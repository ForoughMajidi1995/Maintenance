# %%
# electricity
from variables_to_specify_electricity import *
from training_utilities_2nd_part import *
from training_utilities import *
df, columns_to_normalize, elect_target_col, forecast_avg_target_col_name, avg_target_col_name, No_of_datapoints_in_one_day, start_date, end_date, delta, one_month_days, out_columns, elect_drop_columnss, elect_windows, index_of_one_month, one_month_window_size, date_col_name = variables_to_specify_electricity()

df = df.dropna().reset_index(drop=True)
df = df.drop(range(1344)).reset_index(drop=True)
# df = df.iloc[:len(df)//10]
electricity_df = df
# elect_time_steps = 48
elect_time_steps = 1


convert_time(electricity_df, date_col_name)
electricity_df
# Out:
#             date  day    period  nswprice  nswdemand  vicprice  vicdemand  \
# 0     1970-01-01    1  0.000000  0.085565   0.541803  0.003467   0.422915
# 1     1970-01-01    1  0.021277  0.085565   0.506992  0.003467   0.422915
# 2     1970-01-01    1  0.042553  0.078209   0.477834  0.003467   0.422915
# 3     1970-01-01    1  0.063830  0.064519   0.415204  0.003467   0.422915
# 4     1970-01-01    1  0.085106  0.064519   0.351532  0.003467   0.422915
# ...          ...  ...       ...       ...        ...       ...        ...
# 42763 1970-01-01    1  0.914894  0.044224   0.340672  0.003033   0.255049
# 42764 1970-01-01    1  0.936170  0.044884   0.355549  0.003072   0.241326
# 42765 1970-01-01    1  0.957447  0.043593   0.340970  0.002983   0.247799
# 42766 1970-01-01    1  0.978723  0.066651   0.329366  0.004630   0.345417
# 42767 1970-01-01    1  1.000000  0.050679   0.288753  0.003542   0.355256
#
#        transfer  class  year  month  hour  minute
# 0      0.414912      1  1970      1     0       0
# 1      0.414912      1  1970      1     0       0
# 2      0.414912      1  1970      1     0       0
# 3      0.414912      0  1970      1     0       0
# 4      0.414912      0  1970      1     0       0
# ...         ...    ...   ...    ...   ...     ...
# 42763  0.405263      0  1970      1     0       0
# 42764  0.420614      0  1970      1     0       0
# 42765  0.362281      0  1970      1     0       0
# 42766  0.206579      1  1970      1     0       0
# 42767  0.231140      0  1970      1     0       0
#
# [42768 rows x 13 columns]

# %% [markdown]
# # stationary

# %%
elect_len_of_training_data_of_stationary_model = 14*No_of_datapoints_in_one_day
train = df[0:elect_len_of_training_data_of_stationary_model] 
test = df[elect_len_of_training_data_of_stationary_model:]

eval_df_first_month, stationary_model1 = stationary_model_with_hptuning(train, test, one_month_window_size, 1, out_columns, elect_target_col, elect_drop_columnss)
# Out:
# Model Type: RandomForestRegressor
# Storage Required: 5.28 MB
# model storage is : 5.283783912658691
#
#
# total_time is:  0.9989849170001435

# %% [markdown]
#  # Model reuse

# %%
daily_df_avg = get_elect_daily_avg(electricity_df, No_of_datapoints_in_one_day, elect_target_col, avg_target_col_name)

seasonality_periods_acf_ls, seasonality_periods_acf, segmented_daily_df_avg, filtered_most_similar_dict_wass, filtered_most_similar_dict_tvd, forecast_daily_df_avg, segmented_forecast_daily_df_avg, filtered_forecasted_most_similar_dict_wass, filtered_forecasted_most_similar_dict_tvd = get_seasonality_segments_and_similarities(daily_df_avg, avg_target_col_name, forecast_avg_target_col_name, 14)
# Out:
# Detected seasonality periods (ACF): [  4   7  10  14  17  21  23  27  34  42  49  53  56  58  63  68  72  76
#   80  85  92  97 104 107 112 114 121]
# median_value is:  58

# %%
df_copy = electricity_df[[elect_target_col]]
target_col = elect_target_col
time_steps = elect_time_steps

df_copy['date'] = pd.to_datetime(df_copy.index)
multiplier = No_of_datapoints_in_one_day
x = 14* multiplier
window_len_=[x]


drift_results_df_ls = []

for i in window_len_:
    start_drift_detection_time = timeit.default_timer()
    drift_results_df = detect_drift_univariate(
        df_copy,
        target_col=elect_target_col,
        window_lengths=window_len_,
        arima_order=(1, 0, 0)
    )
    drift_results_df_ls.append(drift_results_df)
    drift_detection_time = timeit.default_timer() - start_drift_detection_time
    num_true = drift_results_df['drift_detected'].sum()
    print("i is: ", i, " and the Number of True values in 'drift_detected':", num_true, " total number of rows are : ", len(drift_results_df))
    print("drift detection time is: ", drift_detection_time)
    drift_results_df = drift_results_df_ls[0]
    drift_indices = list(drift_results_df.index[drift_results_df['drift_detected']])
    print("indices are: ", drift_indices)
# Out:
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=134, Test size=134
# Fold 1: Train size=268, Test size=134
# Fold 2: Train size=402, Test size=134
# Fold 3: Train size=536, Test size=134
# Skipping fold 4: Insufficient training or test data.
# i is:  672  and the Number of True values in 'drift_detected': 31  total number of rows are :  62
# drift detection time is:  13.114384875000002
# indices are:  [0, 1, 3, 6, 9, 11, 16, 17, 19, 20, 21, 22, 27, 28, 30, 32, 34, 36, 37, 43, 44, 47, 48, 49, 50, 51, 52, 56, 57, 59, 61]

# %%
eval_df_monthly2, avg_ml_storage1 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_most_similar_dict_wass, stationary_model1, elect_len_of_training_data_of_stationary_model,electricity_df, "SA", elect_target_col, elect_drop_columnss, elect_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  672
# i/window is :  1.0
# Model Type: RandomForestRegressor
# Storage Required: 5.28 MB
#
#
# window is:  1344
# i/window is :  2.0
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  2016
# i/window is :  3.0
# similar_month_index is :  1
# month_index:  3
#
#
#
# window is:  2688
# i/window is :  4.0
# Model Type: RandomForestRegressor
# Storage Required: 5.25 MB
#
#
# window is:  3360
# i/window is :  5.0
# similar_month_index is :  3
# previous_model_i is :  3360
# math.floor(previous_model_i/window) is:  5
# len(models_ls) is: 4
# Model Type: RandomForestRegressor
# Storage Required: 5.20 MB
#
#
# window is:  4032
# i/window is :  6.0
# Model Type: RandomForestRegressor
# Storage Required: 5.20 MB
#
#
# window is:  4704
# i/window is :  7.0
# similar_month_index is :  5
# previous_model_i is :  4704
# math.floor(previous_model_i/window) is:  7
# len(models_ls) is: 6
# Model Type: RandomForestRegressor
# Storage Required: 5.19 MB
#
#
# window is:  5376
# i/window is :  8.0
# similar_month_index is :  0
# month_index:  8
#
#
#
# window is:  6048
# i/window is :  9.0
# similar_month_index is :  0
# month_index:  9
#
#
#
# window is:  6720
# i/window is :  10.0
# similar_month_index is :  8
# previous_model_i is :  6720
# math.floor(previous_model_i/window) is:  10
# len(models_ls) is: 9
# Model Type: RandomForestRegressor
# Storage Required: 5.05 MB
#
#
# window is:  7392
# i/window is :  11.0
# similar_month_index is :  8
# previous_model_i is :  7392
# math.floor(previous_model_i/window) is:  11
# len(models_ls) is: 10
# Model Type: RandomForestRegressor
# Storage Required: 5.16 MB
#
#
# window is:  8064
# i/window is :  12.0
# similar_month_index is :  7
# previous_model_i is :  8064
# math.floor(previous_model_i/window) is:  12
# len(models_ls) is: 11
# Model Type: RandomForestRegressor
# Storage Required: 5.02 MB
#
#
# window is:  8736
# i/window is :  13.0
# Model Type: RandomForestRegressor
# Storage Required: 5.02 MB
#
#
# window is:  9408
# i/window is :  14.0
# similar_month_index is :  9
# previous_model_i is :  9408
# math.floor(previous_model_i/window) is:  14
# len(models_ls) is: 13
# Model Type: RandomForestRegressor
# Storage Required: 5.27 MB
#
#
# window is:  10080
# i/window is :  15.0
# similar_month_index is :  8
# previous_model_i is :  10080
# math.floor(previous_model_i/window) is:  15
# len(models_ls) is: 14
# Model Type: RandomForestRegressor
# Storage Required: 5.02 MB
#
#
# window is:  10752
# i/window is :  16.0
# similar_month_index is :  10
# previous_model_i is :  10752
# math.floor(previous_model_i/window) is:  16
# len(models_ls) is: 15
# Model Type: RandomForestRegressor
# Storage Required: 5.24 MB
#
#
# window is:  11424
# i/window is :  17.0
# similar_month_index is :  5
# previous_model_i is :  11424
# math.floor(previous_model_i/window) is:  17
# len(models_ls) is: 16
# Model Type: RandomForestRegressor
# Storage Required: 5.08 MB
#
#
# window is:  12096
# i/window is :  18.0
# similar_month_index is :  2
# month_index:  18
#
#
#
# window is:  12768
# i/window is :  19.0
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  13440
# i/window is :  20.0
# similar_month_index is :  6
# month_index:  20
#
#
#
#
# window is:  14112
# i/window is :  21.0
# similar_month_index is :  18
# previous_model_i is :  14112
# math.floor(previous_model_i/window) is:  21
# len(models_ls) is: 20
# Model Type: RandomForestRegressor
# Storage Required: 5.10 MB
#
#
# window is:  14784
# i/window is :  22.0
# similar_month_index is :  5
# previous_model_i is :  14784
# math.floor(previous_model_i/window) is:  22
# len(models_ls) is: 21
# Model Type: RandomForestRegressor
# Storage Required: 5.74 MB
#
#
# window is:  15456
# i/window is :  23.0
# similar_month_index is :  19
# month_index:  23
#
#
#
#
# window is:  16128
# i/window is :  24.0
# Model Type: RandomForestRegressor
# Storage Required: 5.55 MB
#
#
# window is:  16800
# i/window is :  25.0
# similar_month_index is :  19
# month_index:  25
#
#
#
#
# window is:  17472
# i/window is :  26.0
# Model Type: RandomForestRegressor
# Storage Required: 5.46 MB
#
#
# window is:  18144
# i/window is :  27.0
# similar_month_index is :  25
# previous_model_i is :  18144
# math.floor(previous_model_i/window) is:  27
# len(models_ls) is: 26
# Model Type: RandomForestRegressor
# Storage Required: 5.03 MB
#
#
# window is:  18816
# i/window is :  28.0
# similar_month_index is :  26
# month_index:  28
#
#
#
#
# window is:  19488
# i/window is :  29.0
# Model Type: RandomForestRegressor
# Storage Required: 5.09 MB
#
#
# window is:  20160
# i/window is :  30.0
# Model Type: RandomForestRegressor
# Storage Required: 5.40 MB
#
#
# window is:  20832
# i/window is :  31.0
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  21504
# i/window is :  32.0
# similar_month_index is :  30
# month_index:  32
#
#
#
#
# window is:  22176
# i/window is :  33.0
# similar_month_index is :  24
# month_index:  33
#
#
#
#
# window is:  22848
# i/window is :  34.0
# similar_month_index is :  27
# previous_model_i is :  22848
# math.floor(previous_model_i/window) is:  34
# len(models_ls) is: 33
# Model Type: RandomForestRegressor
# Storage Required: 5.26 MB
#
#
# window is:  23520
# i/window is :  35.0
# similar_month_index is :  29
# month_index:  35
#
#
#
#
# window is:  24192
# i/window is :  36.0
# similar_month_index is :  24
# month_index:  36
#
#
#
#
# window is:  24864
# i/window is :  37.0
# similar_month_index is :  30
# month_index:  37
#
#
#
#
# window is:  25536
# i/window is :  38.0
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  26208
# i/window is :  39.0
# similar_month_index is :  37
# previous_model_i is :  26208
# math.floor(previous_model_i/window) is:  39
# len(models_ls) is: 38
# Model Type: RandomForestRegressor
# Storage Required: 5.10 MB
#
#
# window is:  26880
# i/window is :  40.0
# Model Type: RandomForestRegressor
# Storage Required: 5.10 MB
#
#
# window is:  27552
# i/window is :  41.0
# similar_month_index is :  37
# previous_model_i is :  27552
# math.floor(previous_model_i/window) is:  41
# len(models_ls) is: 40
# Model Type: RandomForestRegressor
# Storage Required: 5.59 MB
#
#
# window is:  28224
# i/window is :  42.0
# similar_month_index is :  38
# month_index:  42
#
#
#
#
# window is:  28896
# i/window is :  43.0
# similar_month_index is :  30
# month_index:  43
#
#
#
#
# window is:  29568
# i/window is :  44.0
# similar_month_index is :  42
# previous_model_i is :  29568
# math.floor(previous_model_i/window) is:  44
# len(models_ls) is: 43
# Model Type: RandomForestRegressor
# Storage Required: 5.23 MB
#
#
# window is:  30240
# i/window is :  45.0
# similar_month_index is :  41
# previous_model_i is :  30240
# math.floor(previous_model_i/window) is:  45
# len(models_ls) is: 44
# Model Type: RandomForestRegressor
# Storage Required: 5.17 MB
#
#
# window is:  30912
# i/window is :  46.0
# similar_month_index is :  41
# previous_model_i is :  30912
# math.floor(previous_model_i/window) is:  46
# len(models_ls) is: 45
# Model Type: RandomForestRegressor
# Storage Required: 5.07 MB
#
#
# window is:  31584
# i/window is :  47.0
# similar_month_index is :  44
# previous_model_i is :  31584
# math.floor(previous_model_i/window) is:  47
# len(models_ls) is: 46
# Model Type: RandomForestRegressor
# Storage Required: 4.82 MB
#
#
# window is:  32256
# i/window is :  48.0
# similar_month_index is :  35
# previous_model_i is :  32256
# math.floor(previous_model_i/window) is:  48
# len(models_ls) is: 47
# Model Type: RandomForestRegressor
# Storage Required: 5.41 MB
#
#
# window is:  32928
# i/window is :  49.0
# similar_month_index is :  1
# month_index:  49
#
#
#
#
# window is:  33600
# i/window is :  50.0
# similar_month_index is :  41
# previous_model_i is :  33600
# math.floor(previous_model_i/window) is:  50
# len(models_ls) is: 49
# Model Type: RandomForestRegressor
# Storage Required: 5.39 MB
#
#
# window is:  34272
# i/window is :  51.0
# similar_month_index is :  49
# previous_model_i is :  34272
# math.floor(previous_model_i/window) is:  51
# len(models_ls) is: 50
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
#
#
# window is:  34944
# i/window is :  52.0
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
#
#
# window is:  35616
# i/window is :  53.0
# similar_month_index is :  17
# previous_model_i is :  35616
# math.floor(previous_model_i/window) is:  53
# len(models_ls) is: 52
# Model Type: RandomForestRegressor
# Storage Required: 5.62 MB
#
#
# window is:  36288
# i/window is :  54.0
# similar_month_index is :  14
# previous_model_i is :  36288
# math.floor(previous_model_i/window) is:  54
# len(models_ls) is: 53
# Model Type: RandomForestRegressor
# Storage Required: 5.74 MB
#
#
# window is:  36960
# i/window is :  55.0
# similar_month_index is :  10
# previous_model_i is :  36960
# math.floor(previous_model_i/window) is:  55
# len(models_ls) is: 54
# Model Type: RandomForestRegressor
# Storage Required: 5.53 MB
#
#
# window is:  37632
# i/window is :  56.0
# similar_month_index is :  53
# previous_model_i is :  37632
# math.floor(previous_model_i/window) is:  56
# len(models_ls) is: 55
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
#
#
# window is:  38304
# i/window is :  57.0
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
#
#
# window is:  38976
# i/window is :  58.0
# similar_month_index is :  20
# previous_model_i is :  38976
# math.floor(previous_model_i/window) is:  58
# len(models_ls) is: 57
# Model Type: RandomForestRegressor
# Storage Required: 5.39 MB
#
#
# window is:  39648
# i/window is :  59.0
# similar_month_index is :  4
# month_index:  59
#
#
#
#
# window is:  40320
# i/window is :  60.0
# similar_month_index is :  58
# previous_model_i is :  40320
# math.floor(previous_model_i/window) is:  60
# len(models_ls) is: 59
# Model Type: RandomForestRegressor
# Storage Required: 5.51 MB
#
#
# window is:  40992
# i/window is :  61.0
# similar_month_index is :  24
# month_index:  61
#
#
#
#
# window is:  41664
# i/window is :  62.0
# similar_month_index is :  2
# month_index:  62
#
#
#
#
# window is:  42336
#
#
# total_reuse_time is :  6.415052374999995
# reuse_trained_and_stored_models_count is :  43
# avg_ml_storage:  5.2884467147117435
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.0017390706903124412
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.0009755872891141497
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.000864547197722094
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.0012394378687078224
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.025832834168231435
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.008827615460550296
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.009028759263604871
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.011484494667213687
# Average mse in random model is:  0.03487731456725129
# average mae in random model is:  0.10722128443613708

# %%
eval_df_monthly2, avg_ml_storage2 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_most_similar_dict_tvd, stationary_model1, elect_len_of_training_data_of_stationary_model,electricity_df, "SA", elect_target_col, elect_drop_columnss, elect_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  672
# i/window is :  1.0
# Model Type: RandomForestRegressor
# Storage Required: 5.28 MB
#
#
# window is:  1344
# i/window is :  2.0
# similar_month_index is :  0
# month_index:  2
#
#
#
#
# window is:  2016
# i/window is :  3.0
# Model Type: RandomForestRegressor
# Storage Required: 5.09 MB
#
#
# window is:  2688
# i/window is :  4.0
# Model Type: RandomForestRegressor
# Storage Required: 5.25 MB
#
#
# window is:  3360
# i/window is :  5.0
# similar_month_index is :  0
# month_index:  5
#
#
#
#
# window is:  4032
# i/window is :  6.0
# Model Type: RandomForestRegressor
# Storage Required: 5.20 MB
#
#
# window is:  4704
# i/window is :  7.0
# Model Type: RandomForestRegressor
# Storage Required: 5.18 MB
#
#
# window is:  5376
# i/window is :  8.0
# Model Type: RandomForestRegressor
# Storage Required: 5.19 MB
#
#
# window is:  6048
# i/window is :  9.0
# similar_month_index is :  2
# previous_model_i is :  6048
# math.floor(previous_model_i/window) is:  9
# len(models_ls) is: 8
# Model Type: RandomForestRegressor
# Storage Required: 5.08 MB
#
#
# window is:  6720
# i/window is :  10.0
# similar_month_index is :  6
# month_index:  10
#
#
#
# window is:  7392
# i/window is :  11.0
# similar_month_index is :  7
# month_index:  11
#
#
#
#
# window is:  8064
# i/window is :  12.0
# similar_month_index is :  10
# previous_model_i is :  8064
# math.floor(previous_model_i/window) is:  12
# len(models_ls) is: 11
# Model Type: RandomForestRegressor
# Storage Required: 5.02 MB
#
#
# window is:  8736
# i/window is :  13.0
# similar_month_index is :  7
# month_index:  13
#
#
#
#
# window is:  9408
# i/window is :  14.0
# similar_month_index is :  7
# month_index:  14
#
#
#
#
# window is:  10080
# i/window is :  15.0
# similar_month_index is :  7
# month_index:  15
#
#
#
#
# window is:  10752
# i/window is :  16.0
# similar_month_index is :  8
# month_index:  16
#
#
#
#
# window is:  11424
# i/window is :  17.0
# Model Type: RandomForestRegressor
# Storage Required: 5.24 MB
#
#
# window is:  12096
# i/window is :  18.0
# similar_month_index is :  7
# month_index:  18
#
#
#
#
# window is:  12768
# i/window is :  19.0
# similar_month_index is :  15
# previous_model_i is :  12768
# math.floor(previous_model_i/window) is:  19
# len(models_ls) is: 18
# Model Type: RandomForestRegressor
# Storage Required: 5.07 MB
#
#
# window is:  13440
# i/window is :  20.0
# similar_month_index is :  15
# previous_model_i is :  13440
# math.floor(previous_model_i/window) is:  20
# len(models_ls) is: 19
# Model Type: RandomForestRegressor
# Storage Required: 5.31 MB
#
#
# window is:  14112
# i/window is :  21.0
# similar_month_index is :  19
# previous_model_i is :  14112
# math.floor(previous_model_i/window) is:  21
# len(models_ls) is: 20
# Model Type: RandomForestRegressor
# Storage Required: 5.10 MB
#
#
# window is:  14784
# i/window is :  22.0
# similar_month_index is :  15
# previous_model_i is :  14784
# math.floor(previous_model_i/window) is:  22
# len(models_ls) is: 21
# Model Type: RandomForestRegressor
# Storage Required: 5.74 MB
#
#
# window is:  15456
# i/window is :  23.0
# similar_month_index is :  17
# month_index:  23
#
#
#
#
# window is:  16128
# i/window is :  24.0
# Model Type: RandomForestRegressor
# Storage Required: 5.55 MB
#
#
# window is:  16800
# i/window is :  25.0
# similar_month_index is :  23
# previous_model_i is :  16800
# math.floor(previous_model_i/window) is:  25
# len(models_ls) is: 24
# Model Type: RandomForestRegressor
# Storage Required: 5.46 MB
#
#
# window is:  17472
# i/window is :  26.0
# similar_month_index is :  15
# previous_model_i is :  17472
# math.floor(previous_model_i/window) is:  26
# len(models_ls) is: 25
# Model Type: RandomForestRegressor
# Storage Required: 5.25 MB
#
#
# window is:  18144
# i/window is :  27.0
# similar_month_index is :  7
# month_index:  27
#
#
#
#
# window is:  18816
# i/window is :  28.0
# Model Type: RandomForestRegressor
# Storage Required: 5.03 MB
#
#
# window is:  19488
# i/window is :  29.0
# similar_month_index is :  23
# previous_model_i is :  19488
# math.floor(previous_model_i/window) is:  29
# len(models_ls) is: 28
# Model Type: RandomForestRegressor
# Storage Required: 5.40 MB
#
#
# window is:  20160
# i/window is :  30.0
# similar_month_index is :  14
# previous_model_i is :  20160
# math.floor(previous_model_i/window) is:  30
# len(models_ls) is: 29
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  20832
# i/window is :  31.0
# similar_month_index is :  9
# previous_model_i is :  20832
# math.floor(previous_model_i/window) is:  31
# len(models_ls) is: 30
# Model Type: RandomForestRegressor
# Storage Required: 5.15 MB
#
#
# window is:  21504
# i/window is :  32.0
# similar_month_index is :  1
# month_index:  32
#
#
#
#
# window is:  22176
# i/window is :  33.0
# similar_month_index is :  24
# month_index:  33
#
#
#
#
# window is:  22848
# i/window is :  34.0
# similar_month_index is :  25
# previous_model_i is :  22848
# math.floor(previous_model_i/window) is:  34
# len(models_ls) is: 33
# Model Type: RandomForestRegressor
# Storage Required: 5.26 MB
#
#
# window is:  23520
# i/window is :  35.0
# similar_month_index is :  28
# month_index:  35
#
#
#
#
# window is:  24192
# i/window is :  36.0
# similar_month_index is :  14
# previous_model_i is :  24192
# math.floor(previous_model_i/window) is:  36
# len(models_ls) is: 35
# Model Type: RandomForestRegressor
# Storage Required: 5.51 MB
#
#
# window is:  24864
# i/window is :  37.0
# similar_month_index is :  26
# previous_model_i is :  24864
# math.floor(previous_model_i/window) is:  37
# len(models_ls) is: 36
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  25536
# i/window is :  38.0
# similar_month_index is :  16
# previous_model_i is :  25536
# math.floor(previous_model_i/window) is:  38
# len(models_ls) is: 37
# Model Type: RandomForestRegressor
# Storage Required: 5.24 MB
#
#
# window is:  26208
# i/window is :  39.0
# similar_month_index is :  22
# previous_model_i is :  26208
# math.floor(previous_model_i/window) is:  39
# len(models_ls) is: 38
# Model Type: RandomForestRegressor
# Storage Required: 5.10 MB
#
#
# window is:  26880
# i/window is :  40.0
# similar_month_index is :  26
# previous_model_i is :  26880
# math.floor(previous_model_i/window) is:  40
# len(models_ls) is: 39
# Model Type: RandomForestRegressor
# Storage Required: 5.60 MB
#
#
# window is:  27552
# i/window is :  41.0
# similar_month_index is :  19
# previous_model_i is :  27552
# math.floor(previous_model_i/window) is:  41
# len(models_ls) is: 40
# Model Type: RandomForestRegressor
# Storage Required: 5.59 MB
#
#
# window is:  28224
# i/window is :  42.0
# similar_month_index is :  26
# previous_model_i is :  28224
# math.floor(previous_model_i/window) is:  42
# len(models_ls) is: 41
# Model Type: RandomForestRegressor
# Storage Required: 5.32 MB
#
#
# window is:  28896
# i/window is :  43.0
# similar_month_index is :  31
# previous_model_i is :  28896
# math.floor(previous_model_i/window) is:  43
# len(models_ls) is: 42
# Model Type: RandomForestRegressor
# Storage Required: 5.35 MB
#
#
# window is:  29568
# i/window is :  44.0
# similar_month_index is :  26
# previous_model_i is :  29568
# math.floor(previous_model_i/window) is:  44
# len(models_ls) is: 43
# Model Type: RandomForestRegressor
# Storage Required: 5.23 MB
#
#
# window is:  30240
# i/window is :  45.0
# similar_month_index is :  7
# month_index:  45
#
#
#
#
# window is:  30912
# i/window is :  46.0
# similar_month_index is :  23
# previous_model_i is :  30912
# math.floor(previous_model_i/window) is:  46
# len(models_ls) is: 45
# Model Type: RandomForestRegressor
# Storage Required: 5.07 MB
#
#
# window is:  31584
# i/window is :  47.0
# similar_month_index is :  26
# previous_model_i is :  31584
# math.floor(previous_model_i/window) is:  47
# len(models_ls) is: 46
# Model Type: RandomForestRegressor
# Storage Required: 4.82 MB
#
#
# window is:  32256
# i/window is :  48.0
# similar_month_index is :  4
# month_index:  48
#
#
#
#
# window is:  32928
# i/window is :  49.0
# similar_month_index is :  16
# previous_model_i is :  32928
# math.floor(previous_model_i/window) is:  49
# len(models_ls) is: 48
# Model Type: RandomForestRegressor
# Storage Required: 5.52 MB
#
#
# window is:  33600
# i/window is :  50.0
# similar_month_index is :  16
# previous_model_i is :  33600
# math.floor(previous_model_i/window) is:  50
# len(models_ls) is: 49
# Model Type: RandomForestRegressor
# Storage Required: 5.39 MB
#
#
# window is:  34272
# i/window is :  51.0
# similar_month_index is :  35
# previous_model_i is :  34272
# math.floor(previous_model_i/window) is:  51
# len(models_ls) is: 50
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
#
#
# window is:  34944
# i/window is :  52.0
# similar_month_index is :  6
# month_index:  52
#
#
#
#
# window is:  35616
# i/window is :  53.0
# similar_month_index is :  23
# previous_model_i is :  35616
# math.floor(previous_model_i/window) is:  53
# len(models_ls) is: 52
# Model Type: RandomForestRegressor
# Storage Required: 5.62 MB
#
#
# window is:  36288
# i/window is :  54.0
# similar_month_index is :  42
# previous_model_i is :  36288
# math.floor(previous_model_i/window) is:  54
# len(models_ls) is: 53
# Model Type: RandomForestRegressor
# Storage Required: 5.74 MB
#
#
# window is:  36960
# i/window is :  55.0
# similar_month_index is :  27
# previous_model_i is :  36960
# math.floor(previous_model_i/window) is:  55
# len(models_ls) is: 54
# Model Type: RandomForestRegressor
# Storage Required: 5.53 MB
#
#
# window is:  37632
# i/window is :  56.0
# similar_month_index is :  47
# previous_model_i is :  37632
# math.floor(previous_model_i/window) is:  56
# len(models_ls) is: 55
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
#
#
# window is:  38304
# i/window is :  57.0
# similar_month_index is :  25
# previous_model_i is :  38304
# math.floor(previous_model_i/window) is:  57
# len(models_ls) is: 56
# Model Type: RandomForestRegressor
# Storage Required: 5.52 MB
#
#
# window is:  38976
# i/window is :  58.0
# Model Type: RandomForestRegressor
# Storage Required: 5.52 MB
#
#
# window is:  39648
# i/window is :  59.0
# similar_month_index is :  22
# previous_model_i is :  39648
# math.floor(previous_model_i/window) is:  59
# len(models_ls) is: 58
# Model Type: RandomForestRegressor
# Storage Required: 5.71 MB
#
#
# window is:  40320
# i/window is :  60.0
# similar_month_index is :  57
# previous_model_i is :  40320
# math.floor(previous_model_i/window) is:  60
# len(models_ls) is: 59
# Model Type: RandomForestRegressor
# Storage Required: 5.51 MB
#
#
# window is:  40992
# i/window is :  61.0
# similar_month_index is :  2
# previous_model_i is :  40992
# math.floor(previous_model_i/window) is:  61
# len(models_ls) is: 60
# Model Type: RandomForestRegressor
# Storage Required: 5.44 MB
#
#
# window is:  41664
# i/window is :  62.0
# similar_month_index is :  35
# previous_model_i is :  41664
# math.floor(previous_model_i/window) is:  62
# len(models_ls) is: 61
# Model Type: RandomForestRegressor
# Storage Required: 5.61 MB
#
#
# window is:  42336
#
#
# total_reuse_time is :  7.1695286650000085
# reuse_trained_and_stored_models_count is :  45
# avg_ml_storage:  5.340680885314941
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.0017390706903124412
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.0009755872891141497
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.0005188115164302047
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.0016576605149746751
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.025832834168231435
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.008827615460550296
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.009100453163744547
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.012463048564601488
# Average mse in random model is:  0.03487731456725129
# average mae in random model is:  0.10722128443613708

# %%
eval_df_monthly2, avg_ml_storage3 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_forecasted_most_similar_dict_wass, stationary_model1, elect_len_of_training_data_of_stationary_model,electricity_df, "ES", elect_target_col, elect_drop_columnss, elect_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  672
# Model Type: RandomForestRegressor
# Storage Required: 5.28 MB
#
#
# window is:  1344
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  2016
# Model Type: RandomForestRegressor
# Storage Required: 5.09 MB
#
#
# window is:  2688
# similar_month_index is :  1
# month_index:  3
#
#
#
#
# window is:  3360
# similar_month_index is :  1
# month_index:  4
#
#
#
# window is:  4032
# Model Type: RandomForestRegressor
# Storage Required: 5.20 MB
#
#
# window is:  4704
# similar_month_index is :  2
# month_index:  6
#
#
#
#
# window is:  5376
# Model Type: RandomForestRegressor
# Storage Required: 5.19 MB
#
#
# window is:  6048
# similar_month_index is :  4
# previous_model_i is :  6048
# math.floor(previous_model_i/window) is:  9
# len(models_ls) is: 8
# Model Type: RandomForestRegressor
# Storage Required: 5.08 MB
#
#
# window is:  6720
# similar_month_index is :  1
# month_index:  9
#
#
#
#
# window is:  7392
# similar_month_index is :  3
# previous_model_i is :  7392
# math.floor(previous_model_i/window) is:  11
# len(models_ls) is: 10
# Model Type: RandomForestRegressor
# Storage Required: 5.16 MB
#
#
# window is:  8064
# similar_month_index is :  5
# month_index:  11
#
#
#
#
# window is:  8736
# similar_month_index is :  3
# previous_model_i is :  8736
# math.floor(previous_model_i/window) is:  13
# len(models_ls) is: 12
# Model Type: RandomForestRegressor
# Storage Required: 4.58 MB
#
#
# window is:  9408
# similar_month_index is :  2
# month_index:  13
#
#
#
# window is:  10080
# similar_month_index is :  1
# month_index:  14
#
#
#
#
# window is:  10752
# similar_month_index is :  12
# previous_model_i is :  10752
# math.floor(previous_model_i/window) is:  16
# len(models_ls) is: 15
# Model Type: RandomForestRegressor
# Storage Required: 5.24 MB
#
#
# window is:  11424
# Model Type: RandomForestRegressor
# Storage Required: 5.24 MB
#
#
# window is:  12096
# similar_month_index is :  9
# previous_model_i is :  12096
# math.floor(previous_model_i/window) is:  18
# len(models_ls) is: 17
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  12768
# similar_month_index is :  8
# previous_model_i is :  12768
# math.floor(previous_model_i/window) is:  19
# len(models_ls) is: 18
# Model Type: RandomForestRegressor
# Storage Required: 5.07 MB
#
#
# window is:  13440
# similar_month_index is :  16
# month_index:  19
#
#
#
# window is:  14112
# similar_month_index is :  6
# previous_model_i is :  14112
# math.floor(previous_model_i/window) is:  21
# len(models_ls) is: 20
# Model Type: RandomForestRegressor
# Storage Required: 5.10 MB
#
#
# window is:  14784
# similar_month_index is :  13
# previous_model_i is :  14784
# math.floor(previous_model_i/window) is:  22
# len(models_ls) is: 21
# Model Type: RandomForestRegressor
# Storage Required: 5.74 MB
#
#
# window is:  15456
# similar_month_index is :  5
# month_index:  22
#
#
#
#
# window is:  16128
# similar_month_index is :  21
# previous_model_i is :  16128
# math.floor(previous_model_i/window) is:  24
# len(models_ls) is: 23
# Model Type: RandomForestRegressor
# Storage Required: 5.25 MB
#
#
# window is:  16800
# similar_month_index is :  7
# month_index:  24
#
#
#
#
# window is:  17472
# Model Type: RandomForestRegressor
# Storage Required: 5.46 MB
#
#
# window is:  18144
# Model Type: RandomForestRegressor
# Storage Required: 5.25 MB
#
#
# window is:  18816
# Model Type: RandomForestRegressor
# Storage Required: 5.03 MB
#
#
# window is:  19488
# Model Type: RandomForestRegressor
# Storage Required: 5.09 MB
#
#
# window is:  20160
# similar_month_index is :  27
# month_index:  29
#
#
#
#
# window is:  20832
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  21504
# similar_month_index is :  29
# previous_model_i is :  21504
# math.floor(previous_model_i/window) is:  32
# len(models_ls) is: 31
# Model Type: RandomForestRegressor
# Storage Required: 4.75 MB
#
#
# window is:  22176
# similar_month_index is :  27
# month_index:  32
#
#
#
#
# window is:  22848
# similar_month_index is :  30
# month_index:  33
#
#
#
#
# window is:  23520
# similar_month_index is :  25
# month_index:  34
#
#
#
#
# window is:  24192
# similar_month_index is :  32
# previous_model_i is :  24192
# math.floor(previous_model_i/window) is:  36
# len(models_ls) is: 35
# Model Type: RandomForestRegressor
# Storage Required: 5.51 MB
#
#
# window is:  24864
# similar_month_index is :  26
# month_index:  36
#
#
#
#
# window is:  25536
# similar_month_index is :  10
# previous_model_i is :  25536
# math.floor(previous_model_i/window) is:  38
# len(models_ls) is: 37
# Model Type: RandomForestRegressor
# Storage Required: 5.24 MB
#
#
# window is:  26208
# similar_month_index is :  31
# previous_model_i is :  26208
# math.floor(previous_model_i/window) is:  39
# len(models_ls) is: 38
# Model Type: RandomForestRegressor
# Storage Required: 5.10 MB
#
#
# window is:  26880
# similar_month_index is :  33
# previous_model_i is :  26880
# math.floor(previous_model_i/window) is:  40
# len(models_ls) is: 39
# Model Type: RandomForestRegressor
# Storage Required: 5.60 MB
#
#
# window is:  27552
# similar_month_index is :  30
# month_index:  40
#
#
#
# window is:  28224
# similar_month_index is :  39
# previous_model_i is :  28224
# math.floor(previous_model_i/window) is:  42
# len(models_ls) is: 41
# Model Type: RandomForestRegressor
# Storage Required: 5.32 MB
#
#
# window is:  28896
# similar_month_index is :  38
# previous_model_i is :  28896
# math.floor(previous_model_i/window) is:  43
# len(models_ls) is: 42
# Model Type: RandomForestRegressor
# Storage Required: 5.35 MB
#
#
# window is:  29568
# similar_month_index is :  41
# previous_model_i is :  29568
# math.floor(previous_model_i/window) is:  44
# len(models_ls) is: 43
# Model Type: RandomForestRegressor
# Storage Required: 5.23 MB
#
#
# window is:  30240
# similar_month_index is :  29
# previous_model_i is :  30240
# math.floor(previous_model_i/window) is:  45
# len(models_ls) is: 44
# Model Type: RandomForestRegressor
# Storage Required: 5.17 MB
#
#
# window is:  30912
# similar_month_index is :  33
# previous_model_i is :  30912
# math.floor(previous_model_i/window) is:  46
# len(models_ls) is: 45
# Model Type: RandomForestRegressor
# Storage Required: 5.07 MB
#
#
# window is:  31584
# similar_month_index is :  30
# month_index:  46
#
#
#
#
# window is:  32256
# similar_month_index is :  40
# previous_model_i is :  32256
# math.floor(previous_model_i/window) is:  48
# len(models_ls) is: 47
# Model Type: RandomForestRegressor
# Storage Required: 5.41 MB
#
#
# window is:  32928
# similar_month_index is :  45
# previous_model_i is :  32928
# math.floor(previous_model_i/window) is:  49
# len(models_ls) is: 48
# Model Type: RandomForestRegressor
# Storage Required: 5.52 MB
#
#
# window is:  33600
# similar_month_index is :  28
# month_index:  49
#
#
#
#
# window is:  34272
# similar_month_index is :  1
# month_index:  50
#
#
#
#
# window is:  34944
# similar_month_index is :  42
# previous_model_i is :  34944
# math.floor(previous_model_i/window) is:  52
# len(models_ls) is: 51
# Model Type: RandomForestRegressor
# Storage Required: 5.67 MB
#
#
# window is:  35616
# similar_month_index is :  16
# month_index:  52
#
#
#
# window is:  36288
# similar_month_index is :  9
# previous_model_i is :  36288
# math.floor(previous_model_i/window) is:  54
# len(models_ls) is: 53
# Model Type: RandomForestRegressor
# Storage Required: 5.74 MB
#
#
# window is:  36960
# similar_month_index is :  22
# previous_model_i is :  36960
# math.floor(previous_model_i/window) is:  55
# len(models_ls) is: 54
# Model Type: RandomForestRegressor
# Storage Required: 5.53 MB
#
#
# window is:  37632
# similar_month_index is :  16
# month_index:  55
#
#
#
#
# window is:  38304
# similar_month_index is :  19
# previous_model_i is :  38304
# math.floor(previous_model_i/window) is:  57
# len(models_ls) is: 56
# Model Type: RandomForestRegressor
# Storage Required: 5.52 MB
#
#
# window is:  38976
# similar_month_index is :  4
# previous_model_i is :  38976
# math.floor(previous_model_i/window) is:  58
# len(models_ls) is: 57
# Model Type: RandomForestRegressor
# Storage Required: 5.39 MB
#
#
# window is:  39648
# similar_month_index is :  9
# previous_model_i is :  39648
# math.floor(previous_model_i/window) is:  59
# len(models_ls) is: 58
# Model Type: RandomForestRegressor
# Storage Required: 5.71 MB
#
#
# window is:  40320
# similar_month_index is :  11
# previous_model_i is :  40320
# math.floor(previous_model_i/window) is:  60
# len(models_ls) is: 59
# Model Type: RandomForestRegressor
# Storage Required: 5.51 MB
#
#
# window is:  40992
# similar_month_index is :  53
# previous_model_i is :  40992
# math.floor(previous_model_i/window) is:  61
# len(models_ls) is: 60
# Model Type: RandomForestRegressor
# Storage Required: 5.44 MB
#
#
# window is:  41664
# similar_month_index is :  23
# previous_model_i is :  41664
# math.floor(previous_model_i/window) is:  62
# len(models_ls) is: 61
# Model Type: RandomForestRegressor
# Storage Required: 5.61 MB
#
#
# window is:  42336
#
#
# total_reuse_time is :  6.3960989630000356
# reuse_trained_and_stored_models_count is :  41
# avg_ml_storage:  5.2946362611724105
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.0017390706903124412
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.0009755872891141497
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.0003832502935481965
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.0009312340208075121
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.025832834168231435
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.008827615460550296
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.008265054221504193
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.009206346536450648
# Average mse in random model is:  0.03487731456725129
# average mae in random model is:  0.10722128443613708

# %%
eval_df_monthly2, avg_ml_storage4 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_forecasted_most_similar_dict_tvd, stationary_model1, elect_len_of_training_data_of_stationary_model,electricity_df, "ES", elect_target_col, elect_drop_columnss, elect_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  672
# Model Type: RandomForestRegressor
# Storage Required: 5.28 MB
#
#
# window is:  1344
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  2016
# Model Type: RandomForestRegressor
# Storage Required: 5.09 MB
#
#
# window is:  2688
# similar_month_index is :  1
# month_index:  3
#
#
#
#
# window is:  3360
# similar_month_index is :  1
# month_index:  4
#
#
#
#
# window is:  4032
# Model Type: RandomForestRegressor
# Storage Required: 5.20 MB
#
#
# window is:  4704
# Model Type: RandomForestRegressor
# Storage Required: 5.18 MB
#
#
# window is:  5376
# similar_month_index is :  4
# previous_model_i is :  5376
# math.floor(previous_model_i/window) is:  8
# len(models_ls) is: 7
# Model Type: RandomForestRegressor
# Storage Required: 5.14 MB
#
#
# window is:  6048
# similar_month_index is :  1
# month_index:  8
#
#
#
# window is:  6720
# similar_month_index is :  1
# month_index:  9
#
#
#
#
# window is:  7392
# similar_month_index is :  1
# month_index:  10
#
#
#
#
# window is:  8064
# Model Type: RandomForestRegressor
# Storage Required: 5.16 MB
#
#
# window is:  8736
# Model Type: RandomForestRegressor
# Storage Required: 5.02 MB
#
#
# window is:  9408
# similar_month_index is :  1
# month_index:  13
#
#
#
#
# window is:  10080
# Model Type: RandomForestRegressor
# Storage Required: 5.27 MB
#
#
# window is:  10752
# Model Type: RandomForestRegressor
# Storage Required: 5.02 MB
#
#
# window is:  11424
# Model Type: RandomForestRegressor
# Storage Required: 5.24 MB
#
#
# window is:  12096
# similar_month_index is :  14
# month_index:  17
#
#
#
#
# window is:  12768
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  13440
# similar_month_index is :  16
# month_index:  19
#
#
#
#
# window is:  14112
# similar_month_index is :  14
# month_index:  20
#
#
#
# window is:  14784
# similar_month_index is :  15
# month_index:  21
#
#
#
#
# window is:  15456
# similar_month_index is :  19
# previous_model_i is :  15456
# math.floor(previous_model_i/window) is:  23
# len(models_ls) is: 22
# Model Type: RandomForestRegressor
# Storage Required: 5.55 MB
#
#
# window is:  16128
# Model Type: RandomForestRegressor
# Storage Required: 5.55 MB
#
#
# window is:  16800
# similar_month_index is :  21
# previous_model_i is :  16800
# math.floor(previous_model_i/window) is:  25
# len(models_ls) is: 24
# Model Type: RandomForestRegressor
# Storage Required: 5.46 MB
#
#
# window is:  17472
# similar_month_index is :  21
# previous_model_i is :  17472
# math.floor(previous_model_i/window) is:  26
# len(models_ls) is: 25
# Model Type: RandomForestRegressor
# Storage Required: 5.25 MB
#
#
# window is:  18144
# similar_month_index is :  16
# month_index:  26
#
#
#
# window is:  18816
# similar_month_index is :  16
# month_index:  27
#
#
#
#
# window is:  19488
# similar_month_index is :  22
# previous_model_i is :  19488
# math.floor(previous_model_i/window) is:  29
# len(models_ls) is: 28
# Model Type: RandomForestRegressor
# Storage Required: 5.40 MB
#
#
# window is:  20160
# similar_month_index is :  23
# month_index:  29
#
#
#
#
# window is:  20832
# similar_month_index is :  28
# previous_model_i is :  20832
# math.floor(previous_model_i/window) is:  31
# len(models_ls) is: 30
# Model Type: RandomForestRegressor
# Storage Required: 5.15 MB
#
#
# window is:  21504
# similar_month_index is :  19
# previous_model_i is :  21504
# math.floor(previous_model_i/window) is:  32
# len(models_ls) is: 31
# Model Type: RandomForestRegressor
# Storage Required: 4.75 MB
#
#
# window is:  22176
# Model Type: RandomForestRegressor
# Storage Required: 4.75 MB
#
#
# window is:  22848
# Model Type: RandomForestRegressor
# Storage Required: 5.33 MB
#
#
# window is:  23520
# Model Type: RandomForestRegressor
# Storage Required: 5.26 MB
#
#
# window is:  24192
# Model Type: RandomForestRegressor
# Storage Required: 5.36 MB
#
#
# window is:  24864
# Model Type: RandomForestRegressor
# Storage Required: 5.51 MB
#
#
# window is:  25536
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
#
#
# window is:  26208
# similar_month_index is :  36
# month_index:  38
#
#
#
#
# window is:  26880
# Model Type: RandomForestRegressor
# Storage Required: 5.10 MB
#
#
# window is:  27552
# similar_month_index is :  38
# previous_model_i is :  27552
# math.floor(previous_model_i/window) is:  41
# len(models_ls) is: 40
# Model Type: RandomForestRegressor
# Storage Required: 5.59 MB
#
#
# window is:  28224
# Model Type: RandomForestRegressor
# Storage Required: 5.59 MB
#
#
# window is:  28896
# Model Type: RandomForestRegressor
# Storage Required: 5.32 MB
#
#
# window is:  29568
# Model Type: RandomForestRegressor
# Storage Required: 5.35 MB
#
#
# window is:  30240
# Model Type: RandomForestRegressor
# Storage Required: 5.23 MB
#
#
# window is:  30912
# similar_month_index is :  40
# previous_model_i is :  30912
# math.floor(previous_model_i/window) is:  46
# len(models_ls) is: 45
# Model Type: RandomForestRegressor
# Storage Required: 5.07 MB
#
#
# window is:  31584
# similar_month_index is :  41
# month_index:  46
#
#
#
#
# window is:  32256
# similar_month_index is :  42
# month_index:  47
#
#
#
#
# window is:  32928
# similar_month_index is :  42
# month_index:  48
#
#
#
#
# window is:  33600
# similar_month_index is :  42
# month_index:  49
#
#
#
#
# window is:  34272
# similar_month_index is :  46
# previous_model_i is :  34272
# math.floor(previous_model_i/window) is:  51
# len(models_ls) is: 50
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
#
#
# window is:  34944
# similar_month_index is :  44
# month_index:  51
#
#
#
#
# window is:  35616
# similar_month_index is :  41
# month_index:  52
#
#
#
#
# window is:  36288
# similar_month_index is :  51
# previous_model_i is :  36288
# math.floor(previous_model_i/window) is:  54
# len(models_ls) is: 53
# Model Type: RandomForestRegressor
# Storage Required: 5.74 MB
#
#
# window is:  36960
# similar_month_index is :  51
# previous_model_i is :  36960
# math.floor(previous_model_i/window) is:  55
# len(models_ls) is: 54
# Model Type: RandomForestRegressor
# Storage Required: 5.53 MB
#
#
# window is:  37632
# similar_month_index is :  53
# previous_model_i is :  37632
# math.floor(previous_model_i/window) is:  56
# len(models_ls) is: 55
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
#
#
# window is:  38304
# similar_month_index is :  51
# previous_model_i is :  38304
# math.floor(previous_model_i/window) is:  57
# len(models_ls) is: 56
# Model Type: RandomForestRegressor
# Storage Required: 5.52 MB
#
#
# window is:  38976
# similar_month_index is :  53
# previous_model_i is :  38976
# math.floor(previous_model_i/window) is:  58
# len(models_ls) is: 57
# Model Type: RandomForestRegressor
# Storage Required: 5.39 MB
#
#
# window is:  39648
# similar_month_index is :  56
# previous_model_i is :  39648
# math.floor(previous_model_i/window) is:  59
# len(models_ls) is: 58
# Model Type: RandomForestRegressor
# Storage Required: 5.71 MB
#
#
# window is:  40320
# similar_month_index is :  53
# previous_model_i is :  40320
# math.floor(previous_model_i/window) is:  60
# len(models_ls) is: 59
# Model Type: RandomForestRegressor
# Storage Required: 5.51 MB
#
#
# window is:  40992
# similar_month_index is :  53
# previous_model_i is :  40992
# math.floor(previous_model_i/window) is:  61
# len(models_ls) is: 60
# Model Type: RandomForestRegressor
# Storage Required: 5.44 MB
#
#
# window is:  41664
# similar_month_index is :  53
# previous_model_i is :  41664
# math.floor(previous_model_i/window) is:  62
# len(models_ls) is: 61
# Model Type: RandomForestRegressor
# Storage Required: 5.61 MB
#
#
# window is:  42336
#
#
# total_reuse_time is :  6.574669372999892
# reuse_trained_and_stored_models_count is :  42
# avg_ml_storage:  5.318351609366281
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.0017390706903124412
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.0009755872891141497
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.0009762362497420798
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.0008317051533561586
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.025832834168231435
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.008827615460550296
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.010488305123404328
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.008623764527075311
# Average mse in random model is:  0.03487731456725129
# average mae in random model is:  0.10722128443613708

# %%
avg_ml_storage_reuse = (avg_ml_storage1+avg_ml_storage2+avg_ml_storage3+avg_ml_storage4)/4
print(avg_ml_storage_reuse)
# Out:
# 5.310528867641344

# %% [markdown]
# # informed

# %%
informed_update(stationary_model1,electricity_df, target_col, elect_drop_columnss,time_steps, seasonality_periods_acf,No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  672
# Model Type: RandomForestRegressor
# Storage Required: 5.28 MB
# window is:  1344
# window is:  2016
# Model Type: RandomForestRegressor
# Storage Required: 5.09 MB
# window is:  2688
# window is:  3360
# window is:  4032
# Model Type: RandomForestRegressor
# Storage Required: 5.20 MB
# window is:  4704
# window is:  5376
# window is:  6048
# Model Type: RandomForestRegressor
# Storage Required: 5.14 MB
# window is:  6720
# window is:  7392
# Model Type: RandomForestRegressor
# Storage Required: 5.05 MB
# window is:  8064
# window is:  8736
# window is:  9408
# window is:  10080
# window is:  10752
# Model Type: RandomForestRegressor
# Storage Required: 5.02 MB
# window is:  11424
# Model Type: RandomForestRegressor
# Storage Required: 5.24 MB
# window is:  12096
# window is:  12768
# Model Type: RandomForestRegressor
# Storage Required: 5.22 MB
# window is:  13440
# Model Type: RandomForestRegressor
# Storage Required: 5.07 MB
# window is:  14112
# Model Type: RandomForestRegressor
# Storage Required: 5.31 MB
# window is:  14784
# Model Type: RandomForestRegressor
# Storage Required: 5.10 MB
# window is:  15456
# window is:  16128
# window is:  16800
# window is:  17472
# window is:  18144
# Model Type: RandomForestRegressor
# Storage Required: 5.25 MB
# window is:  18816
# Model Type: RandomForestRegressor
# Storage Required: 5.03 MB
# window is:  19488
# window is:  20160
# Model Type: RandomForestRegressor
# Storage Required: 5.40 MB
# window is:  20832
# window is:  21504
# Model Type: RandomForestRegressor
# Storage Required: 5.15 MB
# window is:  22176
# window is:  22848
# Model Type: RandomForestRegressor
# Storage Required: 5.33 MB
# window is:  23520
# window is:  24192
# Model Type: RandomForestRegressor
# Storage Required: 5.36 MB
# window is:  24864
# Model Type: RandomForestRegressor
# Storage Required: 5.51 MB
# window is:  25536
# window is:  26208
# window is:  26880
# window is:  27552
# window is:  28224
# window is:  28896
# Model Type: RandomForestRegressor
# Storage Required: 5.32 MB
# window is:  29568
# Model Type: RandomForestRegressor
# Storage Required: 5.35 MB
# window is:  30240
# window is:  30912
# window is:  31584
# Model Type: RandomForestRegressor
# Storage Required: 5.07 MB
# window is:  32256
# Model Type: RandomForestRegressor
# Storage Required: 4.82 MB
# window is:  32928
# Model Type: RandomForestRegressor
# Storage Required: 5.41 MB
# window is:  33600
# Model Type: RandomForestRegressor
# Storage Required: 5.52 MB
# window is:  34272
# Model Type: RandomForestRegressor
# Storage Required: 5.39 MB
# window is:  34944
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
# window is:  35616
# window is:  36288
# window is:  36960
# window is:  37632
# Model Type: RandomForestRegressor
# Storage Required: 5.53 MB
# window is:  38304
# Model Type: RandomForestRegressor
# Storage Required: 5.57 MB
# window is:  38976
# window is:  39648
# Model Type: RandomForestRegressor
# Storage Required: 5.39 MB
# window is:  40320
# window is:  40992
# Model Type: RandomForestRegressor
# Storage Required: 5.51 MB
# window is:  41664
# window is:  42336
# Informed total_time:  4.908480291999993
# avg_ml_storage:  5.271694374084473

# %% [markdown]
# # periodical

# %%
periodical_retraining_with_hptuning(1, electricity_df, elect_windows, out_columns, elect_target_col, elect_drop_columnss)
# Out:
# window size is :  240
# Model Type: RandomForestRegressor
# Storage Required: 1.58 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.34 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.55 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.64 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.35 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.57 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.50 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.27 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.71 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.34 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.63 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.60 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.61 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.62 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.50 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.42 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.56 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.56 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.41 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.59 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.53 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.61 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.71 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.65 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.60 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.53 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.50 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.49 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.37 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.50 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.44 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.41 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.44 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.32 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.19 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.19 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.30 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.51 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.33 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.69 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.58 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.60 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.64 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.58 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.60 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.73 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.75 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.46 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.45 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.55 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.42 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.62 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.65 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.67 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.65 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.68 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.41 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.07 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.06 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.06 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.06 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.72 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.91 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.98 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.94 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.83 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.95 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.62 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.87 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.76 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.72 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.84 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.88 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.95 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.83 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.76 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.97 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.78 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.82 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.77 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.99 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.99 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.95 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.87 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.84 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.95 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.97 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.86 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.98 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.83 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.84 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.80 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.78 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.00 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.93 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.99 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.93 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.88 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.89 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.78 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.88 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.76 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.89 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.82 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.86 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.83 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.77 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.80 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.65 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.78 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.79 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.94 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.99 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.99 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.97 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.92 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.94 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.07 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.09 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.07 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.06 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.06 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.97 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.06 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.06 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.07 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.98 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.98 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.98 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.03 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.03 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.03 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.99 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.94 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.83 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.98 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.05 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.09 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 1.91 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.00 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 2.02 MB
# window size is :  720
# Model Type: RandomForestRegressor
# Storage Required: 4.48 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.49 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.43 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.62 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.27 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.44 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.58 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.90 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.82 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.37 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.48 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.24 MB
# Model Type: RandomForestRegressor
# Storage Required: 3.68 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.54 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.86 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.83 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.53 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.66 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.39 MB
# Model Type: RandomForestRegressor
# Storage Required: 6.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.66 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.73 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.76 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.11 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.36 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.71 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.45 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.55 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.98 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.72 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.47 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.77 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.74 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.68 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.41 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.76 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.86 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.70 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.74 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.42 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.50 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.33 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.18 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.84 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.80 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.81 MB
# Model Type: RandomForestRegressor
# Storage Required: 6.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 6.07 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.99 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.95 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.94 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.96 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.72 MB
# Model Type: RandomForestRegressor
# Storage Required: 6.09 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.87 MB
# Model Type: RandomForestRegressor
# Storage Required: 5.80 MB
# window size is :  1488
# Model Type: RandomForestRegressor
# Storage Required: 9.38 MB
# Model Type: RandomForestRegressor
# Storage Required: 9.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 9.68 MB
# Model Type: RandomForestRegressor
# Storage Required: 9.83 MB
# Model Type: RandomForestRegressor
# Storage Required: 9.57 MB
# Model Type: RandomForestRegressor
# Storage Required: 8.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 9.22 MB
# Model Type: RandomForestRegressor
# Storage Required: 10.27 MB
# Model Type: RandomForestRegressor
# Storage Required: 9.50 MB
# Model Type: RandomForestRegressor
# Storage Required: 10.54 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.42 MB
# Model Type: RandomForestRegressor
# Storage Required: 11.59 MB
# Model Type: RandomForestRegressor
# Storage Required: 10.90 MB
# Model Type: RandomForestRegressor
# Storage Required: 11.61 MB
# Model Type: RandomForestRegressor
# Storage Required: 10.78 MB
# Model Type: RandomForestRegressor
# Storage Required: 11.44 MB
# Model Type: RandomForestRegressor
# Storage Required: 11.95 MB
# Model Type: RandomForestRegressor
# Storage Required: 11.42 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.15 MB
# Model Type: RandomForestRegressor
# Storage Required: 11.66 MB
# Model Type: RandomForestRegressor
# Storage Required: 11.27 MB
# Model Type: RandomForestRegressor
# Storage Required: 11.03 MB
# Model Type: RandomForestRegressor
# Storage Required: 11.86 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.33 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.45 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.25 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.10 MB
# window size is :  2160
# Model Type: RandomForestRegressor
# Storage Required: 13.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 13.42 MB
# Model Type: RandomForestRegressor
# Storage Required: 14.37 MB
# Model Type: RandomForestRegressor
# Storage Required: 13.31 MB
# Model Type: RandomForestRegressor
# Storage Required: 13.30 MB
# Model Type: RandomForestRegressor
# Storage Required: 14.45 MB
# Model Type: RandomForestRegressor
# Storage Required: 15.25 MB
# Model Type: RandomForestRegressor
# Storage Required: 17.30 MB
# Model Type: RandomForestRegressor
# Storage Required: 16.25 MB
# Model Type: RandomForestRegressor
# Storage Required: 16.70 MB
# Model Type: RandomForestRegressor
# Storage Required: 15.98 MB
# Model Type: RandomForestRegressor
# Storage Required: 17.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 17.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 16.89 MB
# Model Type: RandomForestRegressor
# Storage Required: 16.06 MB
# Model Type: RandomForestRegressor
# Storage Required: 17.25 MB
# Model Type: RandomForestRegressor
# Storage Required: 18.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 17.77 MB
# window size is :  2880
# Model Type: RandomForestRegressor
# Storage Required: 18.49 MB
# Model Type: RandomForestRegressor
# Storage Required: 18.49 MB
# Model Type: RandomForestRegressor
# Storage Required: 18.60 MB
# Model Type: RandomForestRegressor
# Storage Required: 18.38 MB
# Model Type: RandomForestRegressor
# Storage Required: 19.48 MB
# Model Type: RandomForestRegressor
# Storage Required: 22.79 MB
# Model Type: RandomForestRegressor
# Storage Required: 21.97 MB
# Model Type: RandomForestRegressor
# Storage Required: 21.62 MB
# Model Type: RandomForestRegressor
# Storage Required: 22.68 MB
# Model Type: RandomForestRegressor
# Storage Required: 22.76 MB
# Model Type: RandomForestRegressor
# Storage Required: 22.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 22.45 MB
# Model Type: RandomForestRegressor
# Storage Required: 24.02 MB
# window size is :  3600
# Model Type: RandomForestRegressor
# Storage Required: 22.89 MB
# Model Type: RandomForestRegressor
# Storage Required: 23.62 MB
# Model Type: RandomForestRegressor
# Storage Required: 22.50 MB
# Model Type: RandomForestRegressor
# Storage Required: 24.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 28.53 MB
# Model Type: RandomForestRegressor
# Storage Required: 27.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 27.58 MB
# Model Type: RandomForestRegressor
# Storage Required: 28.44 MB
# Model Type: RandomForestRegressor
# Storage Required: 27.30 MB
# Model Type: RandomForestRegressor
# Storage Required: 29.30 MB
# window size is :  4320
# Model Type: RandomForestRegressor
# Storage Required: 27.45 MB
# Model Type: RandomForestRegressor
# Storage Required: 28.32 MB
# Model Type: RandomForestRegressor
# Storage Required: 27.79 MB
# Model Type: RandomForestRegressor
# Storage Required: 32.55 MB
# Model Type: RandomForestRegressor
# Storage Required: 32.97 MB
# Model Type: RandomForestRegressor
# Storage Required: 33.24 MB
# Model Type: RandomForestRegressor
# Storage Required: 34.01 MB
# Model Type: RandomForestRegressor
# Storage Required: 33.39 MB
# average model storage : 6.393299529023492
# optimal MSE seg len time is: 10.99754424999999
# mean_ls is:  [0.0013704955821197563, 0.001007856189413436, 0.0008845265152290545, 0.0008960282822648218, 0.0008995791899776169, 0.0009093778064359212, 0.0009262769652736036]
# np.min(mean_ls) is :  0.0008845265152290545
# optimal_segment_number is : 1488
#
#
#
#
# mean_ls_mae is:  [0.010174309629472694, 0.009397699391283527, 0.009391387233174031, 0.010495064839763375, 0.010490395769764956, 0.010750148022777779, 0.010477672363425923]
# np.min(mean_ls_mae) is :  0.009391387233174031
# optimal_segment_number_mae is : 1488
# optimal MAE seg len time is: 10.99754424999999
#
#
# total_time is:  75.42588225
# ([          Training dataset     Testing dataset       mae       mse      rmse  \
#   0    trained on window i-1  tested on window i  0.027351  0.001025  0.032012
#   1    trained on window i-1  tested on window i  0.024821  0.000968  0.031116
#   2    trained on window i-1  tested on window i  0.023332  0.000858  0.029289
#   3    trained on window i-1  tested on window i  0.042589  0.002354  0.048515
#   4    trained on window i-1  tested on window i  0.016789  0.000569  0.023861
#   ..                     ...                 ...       ...       ...       ...
#   172  trained on window i-1  tested on window i  0.005242  0.000149  0.012220
#   173  trained on window i-1  tested on window i  0.000927  0.000003  0.001703
#   174  trained on window i-1  tested on window i  0.003002  0.000066  0.008129
#   175  trained on window i-1  tested on window i  0.001517  0.000017  0.004142
#   176  trained on window i-1  tested on window i  0.001464  0.000005  0.002309
#
#               r2        mape  training_time  Testing Error  testing_time
#   0    -0.083615   54.807895       0.058366       0.001025      0.002934
#   1    -0.077333   39.602609       0.056529       0.000968      0.002636
#   2     0.210079   29.444716       0.057579       0.000858      0.002757
#   3   -17.420430  100.007523       0.056632       0.002354      0.002590
#   4    -0.545601   24.090188       0.060757       0.000569      0.002785
#   ..         ...         ...            ...            ...           ...
#   172   0.828002    5.314303       0.080896       0.000149      0.003632
#   173   0.988202    2.099914       0.078978       0.000003      0.004199
#   174   0.916805    2.988816       0.080152       0.000066      0.003880
#   175   0.964108    2.446422       0.080457       0.000017      0.003545
#   176   0.987788    2.113209       0.078371       0.000005      0.006714
#
#   [177 rows x 10 columns],
#            Training dataset     Testing dataset       mae       mse      rmse  \
#   0   trained on window i-1  tested on window i  0.024066  0.000911  0.030176
#   1   trained on window i-1  tested on window i  0.016625  0.000568  0.023823
#   2   trained on window i-1  tested on window i  0.022368  0.000702  0.026490
#   3   trained on window i-1  tested on window i  0.020779  0.000713  0.026702
#   4   trained on window i-1  tested on window i  0.016386  0.000406  0.020143
#   5   trained on window i-1  tested on window i  0.012053  0.000262  0.016174
#   6   trained on window i-1  tested on window i  0.018950  0.000519  0.022780
#   7   trained on window i-1  tested on window i  0.015290  0.000371  0.019254
#   8   trained on window i-1  tested on window i  0.017874  0.000470  0.021686
#   9   trained on window i-1  tested on window i  0.014361  0.000321  0.017912
#   10  trained on window i-1  tested on window i  0.016046  0.000352  0.018750
#   11  trained on window i-1  tested on window i  0.014377  0.000310  0.017606
#   12  trained on window i-1  tested on window i  0.021535  0.001158  0.034023
#   13  trained on window i-1  tested on window i  0.015849  0.000371  0.019265
#   14  trained on window i-1  tested on window i  0.010954  0.000181  0.013435
#   15  trained on window i-1  tested on window i  0.014995  0.000329  0.018141
#   16  trained on window i-1  tested on window i  0.015629  0.000354  0.018820
#   17  trained on window i-1  tested on window i  0.007221  0.000138  0.011734
#   18  trained on window i-1  tested on window i  0.012626  0.000226  0.015049
#   19  trained on window i-1  tested on window i  0.008401  0.000238  0.015425
#   20  trained on window i-1  tested on window i  0.013817  0.000549  0.023426
#   21  trained on window i-1  tested on window i  0.003076  0.000087  0.009317
#   22  trained on window i-1  tested on window i  0.005012  0.000192  0.013866
#   23  trained on window i-1  tested on window i  0.001669  0.000007  0.002623
#   24  trained on window i-1  tested on window i  0.003567  0.000118  0.010857
#   25  trained on window i-1  tested on window i  0.001485  0.000005  0.002330
#   26  trained on window i-1  tested on window i  0.002233  0.000018  0.004218
#   27  trained on window i-1  tested on window i  0.003366  0.000184  0.013553
#   28  trained on window i-1  tested on window i  0.001642  0.000019  0.004340
#   29  trained on window i-1  tested on window i  0.000666  0.000009  0.002979
#   30  trained on window i-1  tested on window i  0.000705  0.000002  0.001309
#   31  trained on window i-1  tested on window i  0.001235  0.000167  0.012911
#   32  trained on window i-1  tested on window i  0.001212  0.000003  0.001812
#   33  trained on window i-1  tested on window i  0.028168  0.016663  0.129086
#   34  trained on window i-1  tested on window i  0.001624  0.000010  0.003204
#   35  trained on window i-1  tested on window i  0.002337  0.000214  0.014630
#   36  trained on window i-1  tested on window i  0.003622  0.000587  0.024225
#   37  trained on window i-1  tested on window i  0.005702  0.000220  0.014824
#   38  trained on window i-1  tested on window i  0.004487  0.000132  0.011508
#   39  trained on window i-1  tested on window i  0.007270  0.002702  0.051981
#   40  trained on window i-1  tested on window i  0.008879  0.001019  0.031916
#   41  trained on window i-1  tested on window i  0.003626  0.000033  0.005764
#   42  trained on window i-1  tested on window i  0.002257  0.000025  0.005037
#   43  trained on window i-1  tested on window i  0.002829  0.000019  0.004340
#   44  trained on window i-1  tested on window i  0.010076  0.002691  0.051877
#   45  trained on window i-1  tested on window i  0.016994  0.001269  0.035625
#   46  trained on window i-1  tested on window i  0.011809  0.004976  0.070538
#   47  trained on window i-1  tested on window i  0.037823  0.016063  0.126740
#   48  trained on window i-1  tested on window i  0.011126  0.000607  0.024632
#   49  trained on window i-1  tested on window i  0.005625  0.000114  0.010667
#   50  trained on window i-1  tested on window i  0.008923  0.000287  0.016947
#   51  trained on window i-1  tested on window i  0.003557  0.000350  0.018722
#   52  trained on window i-1  tested on window i  0.002628  0.000020  0.004510
#   53  trained on window i-1  tested on window i  0.002722  0.000054  0.007319
#   54  trained on window i-1  tested on window i  0.003087  0.000064  0.008022
#   55  trained on window i-1  tested on window i  0.001322  0.000066  0.008130
#   56  trained on window i-1  tested on window i  0.001115  0.000004  0.002025
#   57  trained on window i-1  tested on window i  0.001389  0.000010  0.003088
#
#              r2        mape  training_time  Testing Error  testing_time
#   0   -0.063341   47.111886       0.101972       0.000911      0.003522
#   1   -0.267852   23.248210       0.104912       0.000568      0.003634
#   2   -0.089950   40.412063       0.099719       0.000702      0.003436
#   3   -0.253723   27.518799       0.105122       0.000713      0.004649
#   4   -0.591535   30.932933       0.102218       0.000406      0.004183
#   5   -0.304508   17.437601       0.098685       0.000262      0.003738
#   6   -0.630742  145.001867       0.103289       0.000519      0.004249
#   7    0.098340   24.822343       0.103047       0.000371      0.003867
#   8    0.093922   22.257440       0.099904       0.000470      0.003617
#   9    0.239187   18.138800       0.104249       0.000321      0.004134
#   10  -0.003749   23.709537       0.103394       0.000352      0.004015
#   11   0.016149   23.382034       0.100378       0.000310      0.003397
#   12  -0.884039   27.808069       0.099930       0.001158      0.003387
#   13  -0.806677   19.860473       0.107837       0.000371      0.003681
#   14   0.337369   16.357598       0.100187       0.000181      0.003834
#   15  -0.051193   24.972937       0.103088       0.000329      0.004233
#   16  -0.144045   28.805455       0.101330       0.000354      0.003950
#   17   0.160010   11.571808       0.101348       0.000138      0.004536
#   18  -0.335457   21.794041       0.106417       0.000226      0.003533
#   19   0.481658   12.002477       0.106663       0.000238      0.004740
#   20  -0.181924   22.171992       0.129023       0.000549      0.005390
#   21   0.887206         inf       0.171896       0.000087      0.006362
#   22   0.610389         inf       0.189798       0.000192      0.006670
#   23   0.968447         inf       0.194604       0.000007      0.006476
#   24   0.731129    6.682430       0.202545       0.000118      0.006354
#   25   0.976186    3.724003       0.194177       0.000005      0.006074
#   26   0.934426    6.873451       0.184605       0.000018      0.006330
#   27   0.706789    7.151999       0.183002       0.000184      0.006106
#   28   0.986677    3.450003       0.208340       0.000019      0.007118
#   29   0.991961    1.195292       0.218221       0.000009      0.006877
#   30   0.996764    1.305973       0.191156       0.000002      0.006959
#   31   0.718539    1.695850       0.167392       0.000167      0.006608
#   32   0.984599    2.467493       0.176815       0.000003      0.006772
#   33   0.145644    8.999471       0.169341       0.016663      0.007007
#   34   0.894104    4.535637       0.203496       0.000010      0.006535
#   35   0.508329    5.259941       0.184571       0.000214      0.006438
#   36   0.286931    7.244036       0.200524       0.000587      0.006157
#   37  -0.997475   15.940574       0.204478       0.000220      0.005660
#   38   0.635681   13.470342       0.199585       0.000132      0.005817
#   39   0.494591    8.486403       0.196111       0.002702      0.006395
#   40 -19.089738   31.102330       0.224770       0.001019      0.005343
#   41   0.568453    9.411344       0.192600       0.000033      0.005414
#   42   0.803743    6.704247       0.181892       0.000025      0.006154
#   43   0.605906    8.964443       0.181741       0.000019      0.005426
#   44   0.206159    7.309328       0.198744       0.002691      0.006063
#   45   0.694905   38.162825       0.201972       0.001269      0.004983
#   46  -4.204793   36.105541       0.202173       0.004976      0.006888
#   47   0.147076   16.189047       0.205053       0.016063      0.007337
#   48   0.297762   23.765260       0.306833       0.000607      0.006564
#   49   0.855371    8.775961       0.186629       0.000114      0.007460
#   50   0.683874   11.012322       0.189155       0.000287      0.006639
#   51   0.630901    4.425445       0.189610       0.000350      0.007360
#   52   0.957592    4.915089       0.203472       0.000020      0.007013
#   53   0.905269    4.196871       0.210318       0.000054      0.007211
#   54   0.946772    5.091654       0.195850       0.000064      0.007279
#   55   0.902960    1.875464       0.220239       0.000066      0.016444
#   56   0.991339    2.153317       0.213334       0.000004      0.007286
#   57   0.981933    2.293846       0.194220       0.000010      0.007213  ,
#            Training dataset     Testing dataset       mae       mse      rmse  \
#   0   trained on window i-1  tested on window i  0.023219  0.000783  0.027979
#   1   trained on window i-1  tested on window i  0.025767  0.001065  0.032628
#   2   trained on window i-1  tested on window i  0.016893  0.000442  0.021031
#   3   trained on window i-1  tested on window i  0.014941  0.000345  0.018563
#   4   trained on window i-1  tested on window i  0.013078  0.000258  0.016075
#   5   trained on window i-1  tested on window i  0.013103  0.000353  0.018783
#   6   trained on window i-1  tested on window i  0.017578  0.000749  0.027376
#   7   trained on window i-1  tested on window i  0.013060  0.000242  0.015565
#   8   trained on window i-1  tested on window i  0.008608  0.000190  0.013797
#   9   trained on window i-1  tested on window i  0.027313  0.001771  0.042081
#   10  trained on window i-1  tested on window i  0.002753  0.000034  0.005792
#   11  trained on window i-1  tested on window i  0.002525  0.000031  0.005541
#   12  trained on window i-1  tested on window i  0.003078  0.000049  0.006978
#   13  trained on window i-1  tested on window i  0.001240  0.000012  0.003420
#   14  trained on window i-1  tested on window i  0.000842  0.000010  0.003097
#   15  trained on window i-1  tested on window i  0.008718  0.003566  0.059712
#   16  trained on window i-1  tested on window i  0.001261  0.000013  0.003584
#   17  trained on window i-1  tested on window i  0.002926  0.000301  0.017337
#   18  trained on window i-1  tested on window i  0.005385  0.001177  0.034300
#   19  trained on window i-1  tested on window i  0.004510  0.000640  0.025300
#   20  trained on window i-1  tested on window i  0.002714  0.000061  0.007827
#   21  trained on window i-1  tested on window i  0.007533  0.001765  0.042013
#   22  trained on window i-1  tested on window i  0.021547  0.009423  0.097070
#   23  trained on window i-1  tested on window i  0.005938  0.000090  0.009499
#   24  trained on window i-1  tested on window i  0.004464  0.000177  0.013317
#   25  trained on window i-1  tested on window i  0.003211  0.000300  0.017329
#   26  trained on window i-1  tested on window i  0.001362  0.000037  0.006097
#
#             r2       mape  training_time  Testing Error  testing_time
#   0  -0.425716  46.695282       0.196664       0.000783      0.004402
#   1  -1.742271  32.919199       0.198294       0.001065      0.004619
#   2  -0.327394  82.169555       0.190764       0.000442      0.005190
#   3   0.240389  22.703508       0.203364       0.000345      0.005613
#   4   0.324715  18.392882       0.209508       0.000258      0.005598
#   5   0.257472  17.251911       0.339566       0.000353      0.005698
#   6  -1.551046  24.326336       0.208638       0.000749      0.006932
#   7  -0.012986  24.887495       0.212278       0.000242      0.006276
#   8   0.303814  12.787877       0.203522       0.000190      0.006834
#   9  -1.841525        inf       0.206208       0.001771      0.005721
#   10  0.915529        inf       0.425705       0.000034      0.024364
#   11  0.902276   6.255208       0.520747       0.000031      0.010880
#   12  0.892129   9.338763       0.415111       0.000049      0.010998
#   13  0.990431   2.726857       0.418143       0.000012      0.057911
#   14  0.982833   1.644160       0.469039       0.000010      0.012371
#   15  0.635583   4.232574       0.386636       0.003566      0.012546
#   16  0.949420   3.709713       0.424552       0.000013      0.011044
#   17  0.482987   6.822694       0.552092       0.000301      0.010575
#   18  0.559254  10.229646       0.433337       0.001177      0.010246
#   19 -7.563372  13.129255       0.490113       0.000640      0.008640
#   20  0.723645   7.886877       0.402941       0.000061      0.010560
#   21  0.514867   6.091906       0.581585       0.001765      0.012292
#   22  0.080807  25.900666       0.454015       0.009423      0.013336
#   23  0.895064   9.714291       0.480735       0.000090      0.012715
#   24  0.740768   7.013372       0.510769       0.000177      0.012597
#   25  0.668046   4.955936       0.409675       0.000300      0.013733
#   26  0.939495   2.402651       0.428392       0.000037      0.013826  ,
#            Training dataset     Testing dataset       mae       mse      rmse  \
#   0   trained on window i-1  tested on window i  0.019156  0.000557  0.023594
#   1   trained on window i-1  tested on window i  0.019126  0.000606  0.024614
#   2   trained on window i-1  tested on window i  0.018066  0.000538  0.023191
#   3   trained on window i-1  tested on window i  0.013753  0.000320  0.017895
#   4   trained on window i-1  tested on window i  0.017603  0.000525  0.022905
#   5   trained on window i-1  tested on window i  0.008672  0.000201  0.014174
#   6   trained on window i-1  tested on window i  0.031394  0.002054  0.045321
#   7   trained on window i-1  tested on window i  0.002406  0.000018  0.004215
#   8   trained on window i-1  tested on window i  0.003960  0.000069  0.008320
#   9   trained on window i-1  tested on window i  0.000910  0.000010  0.003174
#   10  trained on window i-1  tested on window i  0.005785  0.002276  0.047706
#   11  trained on window i-1  tested on window i  0.006386  0.000823  0.028694
#   12  trained on window i-1  tested on window i  0.005423  0.000914  0.030234
#   13  trained on window i-1  tested on window i  0.002489  0.000019  0.004371
#   14  trained on window i-1  tested on window i  0.008273  0.001797  0.042392
#   15  trained on window i-1  tested on window i  0.014343  0.004858  0.069698
#   16  trained on window i-1  tested on window i  0.008262  0.000220  0.014826
#   17  trained on window i-1  tested on window i  0.002901  0.000324  0.018006
#
#             r2       mape  training_time  Testing Error  testing_time
#   0  -0.120201  34.146187       0.299485       0.000557      0.005529
#   1  -0.737046  62.876210       0.303809       0.000606      0.007485
#   2  -0.210909  22.293585       0.286487       0.000538      0.006475
#   3   0.209670  20.362080       0.292968       0.000320      0.006402
#   4  -0.474291  30.428778       0.284660       0.000525      0.008479
#   5   0.267422  12.789610       0.278453       0.000201      0.008821
#   6  -2.339788        inf       0.314127       0.002054      0.010082
#   7   0.940120        inf       0.566653       0.000018      0.014792
#   8   0.910629  12.135742       0.612041       0.000069      0.014705
#   9   0.986590   1.779370       0.617139       0.000010      0.016583
#   10  0.669899   3.650968       0.561315       0.002276      0.016227
#   11 -0.798235  15.652948       0.630548       0.000823      0.015586
#   12  0.530347  13.083100       0.634994       0.000914      0.013698
#   13  0.785029   7.370995       0.710594       0.000019      0.013567
#   14  0.376317   7.884755       0.595692       0.001797      0.017095
#   15  0.309670   9.978500       0.636795       0.004858      0.016365
#   16  0.719950  12.776018       0.716492       0.000220      0.016596
#   17  0.615424   4.415437       0.615378       0.000324      0.018612  ,
#            Training dataset     Testing dataset       mae       mse      rmse  \
#   0   trained on window i-1  tested on window i  0.016842  0.000486  0.022040
#   1   trained on window i-1  tested on window i  0.017922  0.000451  0.021245
#   2   trained on window i-1  tested on window i  0.014937  0.000355  0.018837
#   3   trained on window i-1  tested on window i  0.021272  0.000642  0.025342
#   4   trained on window i-1  tested on window i  0.020415  0.000773  0.027803
#   5   trained on window i-1  tested on window i  0.002674  0.000018  0.004253
#   6   trained on window i-1  tested on window i  0.002997  0.000063  0.007950
#   7   trained on window i-1  tested on window i  0.004434  0.001743  0.041754
#   8   trained on window i-1  tested on window i  0.005698  0.000651  0.025508
#   9   trained on window i-1  tested on window i  0.003780  0.000680  0.026074
#   10  trained on window i-1  tested on window i  0.007715  0.001601  0.040018
#   11  trained on window i-1  tested on window i  0.012004  0.003608  0.060070
#   12  trained on window i-1  tested on window i  0.005684  0.000622  0.024945
#
#             r2       mape  training_time  Testing Error  testing_time
#   0  -0.358597  54.362578       0.370153       0.000486      0.010218
#   1  -0.035487  28.119772       0.393966       0.000451      0.007678
#   2   0.046206  21.536063       0.390895       0.000355      0.007881
#   3  -1.472591  39.047709       0.372803       0.000642      0.009175
#   4  -0.317160        inf       0.378250       0.000773      0.010782
#   5   0.937900        inf       0.724563       0.000018      0.019289
#   6   0.932071   7.256701       0.833792       0.000063      0.016275
#   7   0.673119   2.930463       0.808685       0.001743      0.023419
#   8  -0.498264  14.282054       0.864819       0.000651      0.019599
#   9   0.521083   8.801851       0.926639       0.000680      0.018657
#   10  0.285578  14.143832       0.927213       0.001601      0.019386
#   11  0.345113   9.662630       0.885182       0.003608      0.022347
#   12  0.237780  10.864854       0.969266       0.000622      0.023869  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.015699  0.000368  0.019190
#   1  trained on window i-1  tested on window i  0.013585  0.000325  0.018035
#   2  trained on window i-1  tested on window i  0.018514  0.000551  0.023475
#   3  trained on window i-1  tested on window i  0.025785  0.001160  0.034065
#   4  trained on window i-1  tested on window i  0.003154  0.000027  0.005178
#   5  trained on window i-1  tested on window i  0.003818  0.001409  0.037539
#   6  trained on window i-1  tested on window i  0.005463  0.000386  0.019644
#   7  trained on window i-1  tested on window i  0.003478  0.000567  0.023820
#   8  trained on window i-1  tested on window i  0.012759  0.004172  0.064592
#   9  trained on window i-1  tested on window i  0.005245  0.000127  0.011288
#
#            r2       mape  training_time  Testing Error  testing_time
#   0  0.048560  58.665116       0.472248       0.000368      0.010533
#   1  0.191307  17.597502       0.478509       0.000325      0.010758
#   2 -0.832123  32.921163       0.487787       0.000551      0.013923
#   3 -1.162685        inf       0.475297       0.001160      0.013162
#   4  0.955422   9.182731       0.959574       0.000027      0.024439
#   5  0.689404   2.700786       1.062399       0.001409      0.027024
#   6 -0.051596  14.221333       1.051239       0.000386      0.022087
#   7  0.505961   8.519742       1.121079       0.000567      0.022153
#   8  0.312822  12.586626       1.188914       0.004172      0.025497
#   9  0.832379   8.922507       1.237258       0.000127      0.026146  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.019690  0.000662  0.025725
#   1  trained on window i-1  tested on window i  0.018549  0.000513  0.022644
#   2  trained on window i-1  tested on window i  0.015922  0.000576  0.024002
#   3  trained on window i-1  tested on window i  0.003533  0.000030  0.005462
#   4  trained on window i-1  tested on window i  0.003345  0.001192  0.034531
#   5  trained on window i-1  tested on window i  0.006827  0.000899  0.029977
#   6  trained on window i-1  tested on window i  0.005829  0.000955  0.030899
#   7  trained on window i-1  tested on window i  0.010125  0.002584  0.050833
#
#            r2       mape  training_time  Testing Error  testing_time
#   0 -0.637234  43.528358       0.576787       0.000662      0.012117
#   1 -0.284367  30.852215       0.639136       0.000513      0.010373
#   2 -0.275635        inf       0.606944       0.000576      0.015493
#   3  0.944544        inf       0.987925       0.000030      0.025770
#   4  0.688831   2.720515       1.350763       0.001192      0.034800
#   5  0.252778  16.795821       1.325190       0.000899      0.026555
#   6  0.384481  11.105290       1.510214       0.000955      0.028891
#   7  0.341971   9.023656       1.383897       0.002584      0.029016  ],
#  1488,
#  2,
#  1488,
#  2)
