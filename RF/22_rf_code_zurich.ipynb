# %%
from training_utilities_2nd_part import *

# %%
# Zurich
from variables_to_specify_zurich import *
df, columns_to_normalize, zurich_target_col, forecast_avg_target_col_name, avg_target_col_name, No_of_datapoints_in_one_day, start_date, end_date, delta, one_month_days, out_columns, zurich_drop_columnss, zurich_windows, index_of_one_month, one_month_window_size, date_col_name = variables_to_specify_zurich()
print(zurich_target_col)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

df = df.dropna().reset_index(drop=True)
zurich_df = df
zurich_time_steps = 1
zurich_df['Timestamp'] = pd.to_datetime(zurich_df['Timestamp'])
convert_time(zurich_df, date_col_name)
zurich_df= zurich_df[zurich_df['Timestamp'].dt.year == 2020]
# Out:
# Value_NE5

# %% [markdown]
# # stationary

# %%
zurich_len_of_training_data_of_stationary_model =14*No_of_datapoints_in_one_day

train = df[0:zurich_len_of_training_data_of_stationary_model] 
test = df[zurich_len_of_training_data_of_stationary_model:]

eval_df_first_month, stationary_model1 = stationary_model_with_hptuning(train, test, one_month_window_size, 1, out_columns, zurich_target_col, zurich_drop_columnss)
# Out:
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# model storage is : 11.682847023010254
#
#
# total_time is:  3.353889583000182

# %% [markdown]
# # Model reuse

# %%
# Model reuse
daily_df_avg = get_elect_daily_avg(zurich_df, No_of_datapoints_in_one_day, zurich_target_col, avg_target_col_name)

seasonality_periods_acf_ls, seasonality_periods_acf, segmented_daily_df_avg, filtered_most_similar_dict_wass, filtered_most_similar_dict_tvd, forecast_daily_df_avg, segmented_forecast_daily_df_avg, filtered_forecasted_most_similar_dict_wass, filtered_forecasted_most_similar_dict_tvd = get_seasonality_segments_and_similarities(daily_df_avg, avg_target_col_name, forecast_avg_target_col_name, 14)
# Out:
# Detected seasonality periods (ACF): [  7  14  21  28  35  42  49  56  63  70  77  84  91  98 105 112 119 126
#  133 140 147 154 161 168 175 182]
# median_value is:  94

# %% [markdown]
# ## drift detection

# %%
df_copy = zurich_df[[zurich_target_col]]
target_col = zurich_target_col
time_steps = zurich_time_steps

df_copy['date'] = pd.to_datetime(df_copy.index)
window_length=[14]
multiplier = No_of_datapoints_in_one_day

x = 14* multiplier
window_len_=[x]

window_length = [x]
drift_results_df_ls = []

for i in window_len_:
    start_drift_detection_time = timeit.default_timer()
    drift_results_df = detect_drift_univariate(
        df_copy,
        target_col=zurich_target_col,
        window_lengths=window_len_,
        arima_order=(1, 0, 0)
    )
    drift_results_df_ls.append(drift_results_df)
    drift_detection_time = timeit.default_timer() - start_drift_detection_time
    num_true = drift_results_df['drift_detected'].sum()
    print("i is: ", i, " and the Number of True values in 'drift_detected':", num_true, " total number of rows are : ", len(drift_results_df))
    print("drift detection time is: ", drift_detection_time)
    drift_results_df = drift_results_df_ls[0]
    drift_indices = list(drift_results_df.index[drift_results_df['drift_detected']])
    print("indices are: ", drift_indices)
# Out:
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=268, Test size=268
# Fold 1: Train size=536, Test size=268
# Fold 2: Train size=804, Test size=268
# Fold 3: Train size=1072, Test size=268
# Skipping fold 4: Insufficient training or test data.
# i is:  1344  and the Number of True values in 'drift_detected': 19  total number of rows are :  25
# drift detection time is:  8.363529457999999
# indices are:  [0, 1, 2, 3, 8, 10, 11, 12, 13, 14, 15, 17, 18, 19, 20, 21, 22, 23, 24]

# %%
eval_df_monthly2, avg_ml_storage1 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_most_similar_dict_wass, stationary_model1, zurich_len_of_training_data_of_stationary_model,zurich_df, "SA", zurich_target_col, zurich_drop_columnss, zurich_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  1344
# i/window is :  1.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  2688
# i/window is :  2.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  4032
# i/window is :  3.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  5376
# i/window is :  4.0
# similar_month_index is :  2
# month_index:  4
#
#
#
#
# window is:  6720
# i/window is :  5.0
# similar_month_index is :  0
# month_index:  5
#
#
#
#
# window is:  8064
# i/window is :  6.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  9408
# i/window is :  7.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  10752
# i/window is :  8.0
# similar_month_index is :  6
# month_index:  8
#
#
#
#
# window is:  12096
# i/window is :  9.0
# similar_month_index is :  5
# previous_model_i is :  12096
# math.floor(previous_model_i/window) is:  9
# len(models_ls) is: 8
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  13440
# i/window is :  10.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  14784
# i/window is :  11.0
# similar_month_index is :  9
# previous_model_i is :  14784
# math.floor(previous_model_i/window) is:  11
# len(models_ls) is: 10
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  16128
# i/window is :  12.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  17472
# i/window is :  13.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  18816
# i/window is :  14.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  20160
# i/window is :  15.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  21504
# i/window is :  16.0
# similar_month_index is :  1
# month_index:  16
#
#
#
#
# window is:  22848
# i/window is :  17.0
# similar_month_index is :  13
# month_index:  17
#
#
#
#
# window is:  24192
# i/window is :  18.0
# similar_month_index is :  3
# month_index:  18
#
#
#
#
# window is:  25536
# i/window is :  19.0
# similar_month_index is :  17
# previous_model_i is :  25536
# math.floor(previous_model_i/window) is:  19
# len(models_ls) is: 18
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  26880
# i/window is :  20.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  28224
# i/window is :  21.0
# similar_month_index is :  19
# previous_model_i is :  28224
# math.floor(previous_model_i/window) is:  21
# len(models_ls) is: 20
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  29568
# i/window is :  22.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  30912
# i/window is :  23.0
# similar_month_index is :  18
# previous_model_i is :  30912
# math.floor(previous_model_i/window) is:  23
# len(models_ls) is: 22
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  32256
# i/window is :  24.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  33600
# i/window is :  25.0
# similar_month_index is :  5
# previous_model_i is :  33600
# math.floor(previous_model_i/window) is:  25
# len(models_ls) is: 24
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  34944
#
#
# total_reuse_time is :  10.382685958000001
# reuse_trained_and_stored_models_count is :  19
# avg_ml_storage:  11.682984352111816
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.009553322659401463
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.006371582225823962
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.005835080919512998
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.00947462949131955
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.07812265004877907
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.05682018752733311
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.047797914765595265
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.07254547818236398
# Average mse in random model is:  0.06008662258127192
# average mae in random model is:  0.19853030673523098

# %%
eval_df_monthly2, avg_ml_storage2 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_most_similar_dict_tvd, stationary_model1, zurich_len_of_training_data_of_stationary_model,zurich_df, "SA", zurich_target_col, zurich_drop_columnss, zurich_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  1344
# i/window is :  1.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  2688
# i/window is :  2.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  4032
# i/window is :  3.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  5376
# i/window is :  4.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  6720
# i/window is :  5.0
# similar_month_index is :  3
# month_index:  5
#
#
#
#
# window is:  8064
# i/window is :  6.0
# similar_month_index is :  3
# month_index:  6
#
#
#
#
# window is:  9408
# i/window is :  7.0
# similar_month_index is :  2
# month_index:  7
#
#
#
#
# window is:  10752
# i/window is :  8.0
# similar_month_index is :  3
# month_index:  8
#
#
#
#
# window is:  12096
# i/window is :  9.0
# similar_month_index is :  1
# month_index:  9
#
#
#
#
# window is:  13440
# i/window is :  10.0
# similar_month_index is :  2
# month_index:  10
#
#
#
#
# window is:  14784
# i/window is :  11.0
# similar_month_index is :  2
# month_index:  11
#
#
#
#
# window is:  16128
# i/window is :  12.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  17472
# i/window is :  13.0
# similar_month_index is :  2
# month_index:  13
#
#
#
#
# window is:  18816
# i/window is :  14.0
# similar_month_index is :  12
# month_index:  14
#
#
#
#
# window is:  20160
# i/window is :  15.0
# similar_month_index is :  9
# previous_model_i is :  20160
# math.floor(previous_model_i/window) is:  15
# len(models_ls) is: 14
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  21504
# i/window is :  16.0
# similar_month_index is :  13
# previous_model_i is :  21504
# math.floor(previous_model_i/window) is:  16
# len(models_ls) is: 15
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  22848
# i/window is :  17.0
# similar_month_index is :  2
# month_index:  17
#
#
#
#
# window is:  24192
# i/window is :  18.0
# similar_month_index is :  1
# month_index:  18
#
#
#
#
# window is:  25536
# i/window is :  19.0
# similar_month_index is :  2
# month_index:  19
#
#
#
#
# window is:  26880
# i/window is :  20.0
# similar_month_index is :  9
# previous_model_i is :  26880
# math.floor(previous_model_i/window) is:  20
# len(models_ls) is: 19
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  28224
# i/window is :  21.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  29568
# i/window is :  22.0
# similar_month_index is :  19
# previous_model_i is :  29568
# math.floor(previous_model_i/window) is:  22
# len(models_ls) is: 21
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  30912
# i/window is :  23.0
# similar_month_index is :  20
# previous_model_i is :  30912
# math.floor(previous_model_i/window) is:  23
# len(models_ls) is: 22
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  32256
# i/window is :  24.0
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  33600
# i/window is :  25.0
# similar_month_index is :  5
# previous_model_i is :  33600
# math.floor(previous_model_i/window) is:  25
# len(models_ls) is: 24
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  34944
#
#
# total_reuse_time is :  7.1130951240000115
# reuse_trained_and_stored_models_count is :  13
# avg_ml_storage:  11.682984352111816
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.009553322659401463
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.006371582225823962
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.007735521651912762
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.007439635617496084
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.07812265004877907
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.05682018752733311
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.057609744580578263
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.06281463827653186
# Average mse in random model is:  0.06008662258127192
# average mae in random model is:  0.19853030673523098

# %%
eval_df_monthly2, avg_ml_storage3 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_forecasted_most_similar_dict_wass, stationary_model1, zurich_len_of_training_data_of_stationary_model,zurich_df, "ES", zurich_target_col, zurich_drop_columnss, zurich_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  1344
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  2688
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  4032
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  5376
# similar_month_index is :  1
# month_index:  3
#
#
#
#
# window is:  6720
# similar_month_index is :  2
# month_index:  4
#
#
#
#
# window is:  8064
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  9408
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  10752
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  12096
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  13440
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  14784
# similar_month_index is :  7
# month_index:  10
#
#
#
#
# window is:  16128
# similar_month_index is :  7
# month_index:  11
#
#
#
#
# window is:  17472
# similar_month_index is :  10
# previous_model_i is :  17472
# math.floor(previous_model_i/window) is:  13
# len(models_ls) is: 12
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  18816
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  20160
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  21504
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  22848
# similar_month_index is :  6
# month_index:  16
#
#
#
#
# window is:  24192
# similar_month_index is :  4
# previous_model_i is :  24192
# math.floor(previous_model_i/window) is:  18
# len(models_ls) is: 17
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  25536
# similar_month_index is :  15
# month_index:  18
#
#
#
#
# window is:  26880
# similar_month_index is :  16
# previous_model_i is :  26880
# math.floor(previous_model_i/window) is:  20
# len(models_ls) is: 19
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  28224
# similar_month_index is :  15
# month_index:  20
#
#
#
#
# window is:  29568
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  30912
# similar_month_index is :  18
# previous_model_i is :  30912
# math.floor(previous_model_i/window) is:  23
# len(models_ls) is: 22
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  32256
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  33600
# similar_month_index is :  6
# month_index:  24
#
#
#
#
# window is:  34944
#
#
# total_reuse_time is :  9.103633333000033
# reuse_trained_and_stored_models_count is :  17
# avg_ml_storage:  11.682984352111816
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.009553322659401463
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.006371582225823962
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.007081999522681815
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.006711688185427443
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.07812265004877907
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.05682018752733311
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.056765372007173104
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.05805424762620971
# Average mse in random model is:  0.06008662258127192
# average mae in random model is:  0.19853030673523098

# %%
eval_df_monthly2, avg_ml_storage4 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_forecasted_most_similar_dict_tvd, stationary_model1, zurich_len_of_training_data_of_stationary_model,zurich_df, "ES", zurich_target_col, zurich_drop_columnss, zurich_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  1344
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  2688
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  4032
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  5376
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  6720
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  8064
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  9408
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  10752
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  12096
# similar_month_index is :  6
# month_index:  8
#
#
#
#
# window is:  13440
# similar_month_index is :  2
# month_index:  9
#
#
#
#
# window is:  14784
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  16128
# similar_month_index is :  8
# previous_model_i is :  16128
# math.floor(previous_model_i/window) is:  12
# len(models_ls) is: 11
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  17472
# similar_month_index is :  9
# previous_model_i is :  17472
# math.floor(previous_model_i/window) is:  13
# len(models_ls) is: 12
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  18816
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  20160
# similar_month_index is :  3
# month_index:  14
#
#
#
#
# window is:  21504
# similar_month_index is :  9
# previous_model_i is :  21504
# math.floor(previous_model_i/window) is:  16
# len(models_ls) is: 15
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  22848
# similar_month_index is :  13
# month_index:  16
#
#
#
#
# window is:  24192
# similar_month_index is :  6
# month_index:  17
#
#
#
#
# window is:  25536
# similar_month_index is :  11
# previous_model_i is :  25536
# math.floor(previous_model_i/window) is:  19
# len(models_ls) is: 18
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  26880
# similar_month_index is :  2
# month_index:  19
#
#
#
#
# window is:  28224
# similar_month_index is :  8
# previous_model_i is :  28224
# math.floor(previous_model_i/window) is:  21
# len(models_ls) is: 20
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  29568
# similar_month_index is :  17
# previous_model_i is :  29568
# math.floor(previous_model_i/window) is:  22
# len(models_ls) is: 21
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  30912
# similar_month_index is :  19
# previous_model_i is :  30912
# math.floor(previous_model_i/window) is:  23
# len(models_ls) is: 22
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  32256
# similar_month_index is :  21
# previous_model_i is :  32256
# math.floor(previous_model_i/window) is:  24
# len(models_ls) is: 23
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  33600
# similar_month_index is :  15
# previous_model_i is :  33600
# math.floor(previous_model_i/window) is:  25
# len(models_ls) is: 24
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
#
#
# window is:  34944
#
#
# total_reuse_time is :  11.371725877000003
# reuse_trained_and_stored_models_count is :  19
# avg_ml_storage:  11.682984352111816
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.009553322659401463
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.006371582225823962
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.006178081416896801
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.0058778426933228075
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.07812265004877907
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.05682018752733311
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.047186592570389714
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.055141852527965184
# Average mse in random model is:  0.06008662258127192
# average mae in random model is:  0.19853030673523098

# %%
avg_ml_storage_reuse = (avg_ml_storage1+avg_ml_storage2+avg_ml_storage3+avg_ml_storage4)/4
print(avg_ml_storage_reuse)
# Out:
# 11.682984352111816

# %% [markdown]
# # informed

# %%
informed_update(stationary_model1,zurich_df, target_col, zurich_drop_columnss,time_steps, seasonality_periods_acf,No_of_datapoints_in_one_day, drift_indices, 1)
# Out:
# window is:  1344
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  2688
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  4032
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  5376
# window is:  6720
# window is:  8064
# window is:  9408
# window is:  10752
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  12096
# window is:  13440
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  14784
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  16128
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  17472
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  18816
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  20160
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  21504
# window is:  22848
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  24192
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  25536
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  26880
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  28224
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  29568
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  30912
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  32256
# Model Type: RandomForestRegressor
# Storage Required: 11.68 MB
# window is:  33600
# window is:  34944
# Informed total_time:  9.667243583000001
# avg_ml_storage:  11.682984352111816

# %% [markdown]
# # periodical

# %%
periodical_retraining_with_hptuning(1, zurich_df, zurich_windows, out_columns, zurich_target_col, zurich_drop_columnss)
# Out:
# window size is :  480
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# Model Type: RandomForestRegressor
# Storage Required: 4.17 MB
# window size is :  1440
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 12.52 MB
# window size is :  2976
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# Model Type: RandomForestRegressor
# Storage Required: 25.85 MB
# window size is :  4320
# Model Type: RandomForestRegressor
# Storage Required: 37.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 37.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 37.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 37.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 37.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 37.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 37.52 MB
# window size is :  5760
# Model Type: RandomForestRegressor
# Storage Required: 50.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 50.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 50.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 50.02 MB
# Model Type: RandomForestRegressor
# Storage Required: 50.02 MB
# window size is :  7200
# Model Type: RandomForestRegressor
# Storage Required: 62.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 62.52 MB
# Model Type: RandomForestRegressor
# Storage Required: 62.52 MB
# window size is :  8640
# Model Type: RandomForestRegressor
# Storage Required: 75.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 75.04 MB
# Model Type: RandomForestRegressor
# Storage Required: 75.04 MB
# average model storage : 14.407432579412692
# optimal MSE seg len time is: 15.836695084000013
# mean_ls is:  [0.012245664205568907, 0.006617445437177297, 0.009528528866460172, 0.0063997138484587, 0.006896265418262666, 0.008519025345424602, 0.006901696857886379]
# np.min(mean_ls) is :  0.0063997138484587
# optimal_segment_number is : 4320
#
#
#
#
# mean_ls_mae is:  [0.07984868607542119, 0.05854420813670159, 0.06791877798695732, 0.05894499091984307, 0.06157301067892886, 0.06968132296403119, 0.06216524365088038]
# np.min(mean_ls_mae) is :  0.05854420813670159
# optimal_segment_number_mae is : 1440
# optimal MAE seg len time is: 14.108270333999997
#
#
# total_time is:  101.274757792
# ([         Training dataset     Testing dataset       mae       mse      rmse  \
#   0   trained on window i-1  tested on window i  0.184500  0.054796  0.234086
#   1   trained on window i-1  tested on window i  0.080195  0.012016  0.109619
#   2   trained on window i-1  tested on window i  0.060163  0.005525  0.074332
#   3   trained on window i-1  tested on window i  0.064545  0.007467  0.086412
#   4   trained on window i-1  tested on window i  0.078561  0.010214  0.101066
#   ..                    ...                 ...       ...       ...       ...
#   67  trained on window i-1  tested on window i  0.085662  0.010837  0.104100
#   68  trained on window i-1  tested on window i  0.059515  0.008281  0.091002
#   69  trained on window i-1  tested on window i  0.089601  0.013306  0.115351
#   70  trained on window i-1  tested on window i  0.100782  0.019219  0.138634
#   71  trained on window i-1  tested on window i  0.084086  0.012272  0.110780
#
#             r2       mape  training_time  Testing Error  testing_time
#   0  -0.317264  38.292728       0.185239       0.054796      0.004296
#   1   0.700373  41.810470       0.177016       0.012016      0.005015
#   2   0.860871  30.518791       0.171803       0.005525      0.004611
#   3   0.827781  21.213023       0.186027       0.007467      0.004764
#   4   0.778025  23.865134       0.178878       0.010214      0.004090
#   ..       ...        ...            ...            ...           ...
#   67  0.685549  22.710858       0.185059       0.010837      0.004724
#   68  0.717234  23.290925       0.175917       0.008281      0.005040
#   69  0.549450  39.880419       0.178764       0.013306      0.004549
#   70  0.083745  37.984150       0.172648       0.019219      0.004241
#   71  0.254604  36.853445       0.181068       0.012272      0.004115
#
#   [72 rows x 10 columns],
#            Training dataset     Testing dataset       mae       mse      rmse  \
#   0   trained on window i-1  tested on window i  0.069732  0.010253  0.101257
#   1   trained on window i-1  tested on window i  0.058446  0.006807  0.082503
#   2   trained on window i-1  tested on window i  0.047302  0.004408  0.066390
#   3   trained on window i-1  tested on window i  0.042730  0.003896  0.062416
#   4   trained on window i-1  tested on window i  0.086400  0.012647  0.112458
#   5   trained on window i-1  tested on window i  0.052502  0.004888  0.069912
#   6   trained on window i-1  tested on window i  0.057719  0.004931  0.070224
#   7   trained on window i-1  tested on window i  0.056091  0.005641  0.075109
#   8   trained on window i-1  tested on window i  0.046171  0.004284  0.065452
#   9   trained on window i-1  tested on window i  0.065410  0.007037  0.083890
#   10  trained on window i-1  tested on window i  0.049394  0.003977  0.063065
#   11  trained on window i-1  tested on window i  0.050992  0.004877  0.069837
#   12  trained on window i-1  tested on window i  0.047237  0.004457  0.066763
#   13  trained on window i-1  tested on window i  0.041454  0.003202  0.056586
#   14  trained on window i-1  tested on window i  0.057863  0.006994  0.083630
#   15  trained on window i-1  tested on window i  0.073562  0.012251  0.110683
#   16  trained on window i-1  tested on window i  0.057318  0.006048  0.077772
#   17  trained on window i-1  tested on window i  0.071825  0.007707  0.087789
#   18  trained on window i-1  tested on window i  0.076620  0.010262  0.101300
#   19  trained on window i-1  tested on window i  0.062304  0.007524  0.086739
#   20  trained on window i-1  tested on window i  0.047323  0.004358  0.066017
#   21  trained on window i-1  tested on window i  0.068142  0.009183  0.095828
#   22  trained on window i-1  tested on window i  0.059980  0.006569  0.081051
#
#             r2       mape  training_time  Testing Error  testing_time
#   0   0.766745  30.404821       0.564124       0.010253      0.008584
#   1   0.837975  25.398082       0.588779       0.006807      0.009386
#   2   0.893127  21.235453       0.573464       0.004408      0.009484
#   3   0.905136  20.337792       0.579377       0.003896      0.009602
#   4   0.314935  33.415680       0.582329       0.012647      0.007984
#   5   0.646536        inf       0.593920       0.004888      0.007097
#   6   0.638885  31.473953       0.565985       0.004931      0.007803
#   7   0.722330  36.338237       0.593825       0.005641      0.008475
#   8   0.789372  27.403265       0.586755       0.004284      0.008018
#   9   0.717507  35.915355       0.575369       0.007037      0.007969
#   10  0.856630  20.619934       0.587462       0.003977      0.007958
#   11  0.835898  16.907724       0.608006       0.004877      0.009259
#   12  0.844822  18.749170       0.578254       0.004457      0.009788
#   13  0.899101  14.397225       0.568187       0.003202      0.009108
#   14  0.791581  20.909086       0.577049       0.006994      0.008559
#   15  0.578831  32.821317       0.582850       0.012251      0.008397
#   16  0.816456  22.065646       0.562546       0.006048      0.009271
#   17  0.739410  30.427122       0.575311       0.007707      0.008686
#   18  0.656112  22.300158       0.598518       0.010262      0.008214
#   19  0.753738  20.707808       0.586641       0.007524      0.009109
#   20  0.850828  19.641296       0.621892       0.004358      0.009083
#   21  0.716020  27.760592       0.599260       0.009183      0.007251
#   22  0.759236  24.826616       0.553199       0.006569      0.008843  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.061802  0.006646  0.081521
#   1  trained on window i-1  tested on window i  0.062960  0.007665  0.087552
#   2  trained on window i-1  tested on window i  0.068971  0.008353  0.091396
#   3  trained on window i-1  tested on window i  0.142763  0.035439  0.188253
#   4  trained on window i-1  tested on window i  0.054747  0.005059  0.071123
#   5  trained on window i-1  tested on window i  0.043501  0.003570  0.059749
#   6  trained on window i-1  tested on window i  0.051259  0.004795  0.069250
#   7  trained on window i-1  tested on window i  0.048410  0.004649  0.068182
#   8  trained on window i-1  tested on window i  0.060376  0.007279  0.085316
#   9  trained on window i-1  tested on window i  0.084398  0.011830  0.108768
#
#            r2       mape  training_time  Testing Error  testing_time
#   0  0.841797  28.737863       1.441331       0.006646      0.017677
#   1  0.735994  26.557610       1.362704       0.007665      0.017954
#   2  0.377893        inf       1.389873       0.008353      0.013912
#   3 -0.715268  44.630999       1.391906       0.035439      0.011807
#   4  0.817610  22.569204       1.371273       0.005059      0.016650
#   5  0.877187  15.686996       1.431267       0.003570      0.016436
#   6  0.854122  17.565581       1.408065       0.004795      0.018576
#   7  0.853341  21.130656       1.268198       0.004649      0.017758
#   8  0.760119  22.713682       1.387661       0.007279      0.016272
#   9  0.599531  33.745825       1.390910       0.011830      0.014162  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.055841  0.005915  0.076906
#   1  trained on window i-1  tested on window i  0.064742  0.007029  0.083837
#   2  trained on window i-1  tested on window i  0.060190  0.006580  0.081119
#   3  trained on window i-1  tested on window i  0.049757  0.004616  0.067943
#   4  trained on window i-1  tested on window i  0.057065  0.006137  0.078339
#   5  trained on window i-1  tested on window i  0.061513  0.007150  0.084556
#   6  trained on window i-1  tested on window i  0.063506  0.007371  0.085857
#
#            r2       mape  training_time  Testing Error  testing_time
#   0  0.831479  27.814546       2.239514       0.005915      0.024959
#   1  0.569673        inf       2.205445       0.007029      0.018435
#   2  0.733220  27.856503       2.238945       0.006580      0.023616
#   3  0.847266  15.806572       2.477273       0.004616      0.024292
#   4  0.810306  21.801258       2.057279       0.006137      0.026392
#   5  0.763380  24.475370       2.115609       0.007150      0.020737
#   6  0.754643  27.459127       2.141072       0.007371      0.023129  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.063568  0.006600  0.081239
#   1  trained on window i-1  tested on window i  0.063282  0.006717  0.081960
#   2  trained on window i-1  tested on window i  0.057157  0.005871  0.076620
#   3  trained on window i-1  tested on window i  0.065429  0.008870  0.094182
#   4  trained on window i-1  tested on window i  0.058429  0.006423  0.080145
#
#            r2       mape  training_time  Testing Error  testing_time
#   0  0.734599        inf       3.001354       0.006600      0.031878
#   1  0.717054  27.575866       3.020691       0.006717      0.032552
#   2  0.813039  17.151433       2.982511       0.005871      0.030652
#   3  0.709090  28.182389       3.007799       0.008870      0.029290
#   4  0.787146  23.640914       3.298068       0.006423      0.029926  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.078346  0.010284  0.101408
#   1  trained on window i-1  tested on window i  0.065931  0.007208  0.084898
#   2  trained on window i-1  tested on window i  0.064767  0.008066  0.089810
#
#            r2       mape  training_time  Testing Error  testing_time
#   0  0.427651        inf       4.125277       0.010284      0.034836
#   1  0.757176  22.315176       3.959974       0.007208      0.049888
#   2  0.744301  26.113370       3.977935       0.008066      0.040795  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.067083  0.007330  0.085616
#   1  trained on window i-1  tested on window i  0.053770  0.005133  0.071643
#   2  trained on window i-1  tested on window i  0.065642  0.008242  0.090787
#
#            r2       mape  training_time  Testing Error  testing_time
#   0  0.655435        inf       4.841689       0.007330      0.033173
#   1  0.836154  17.720917       4.665259       0.005133      0.043067
#   2  0.726720  24.525952       4.393428       0.008242      0.035824  ],
#  4320,
#  3,
#  1440,
#  1)
