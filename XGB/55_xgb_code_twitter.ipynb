# %%
from training_utilities_2nd_part import *
from training_utilities import *

# %%
twitter_df = pd.read_csv("/Users/forough/PycharmProjects/mitigation3/Aiops_data_splitting_paper/code/Multivariate_time_series/twitter2/twitter3.csv")

twitter_df = twitter_df[4: len(twitter_df)-120]
twitter_df['Date'] = pd.to_datetime(twitter_df['Date'])

twitter_df['YearMonth'] = twitter_df['Date'].dt.to_period('M')
one_hot = pd.get_dummies(twitter_df['Symbol'], prefix='Symbol')
twitter_df = pd.concat([twitter_df, one_hot], axis=1)
twitter_df = twitter_df.drop(columns = ['Series', 'Trades', 'Symbol'])
twitter_df
# Out:
#            Date  Prev Close    Open     High     Low   Last   Close    VWAP  \
# 0    2007-11-27      440.00  770.00  1050.00  770.00  959.0  962.90  984.72
# 1    2007-11-28      962.90  984.00   990.00  874.00  885.0  893.90  941.38
# 2    2007-11-29      893.90  909.00   914.75  841.00  887.0  884.20  888.09
# 3    2007-11-30      884.20  890.00   958.00  890.00  929.0  921.55  929.17
# 4    2007-12-03      921.55  939.75   995.00  922.00  980.0  969.30  965.65
# ...         ...         ...     ...      ...     ...    ...     ...     ...
# 3317 2021-04-26      725.35  733.00   739.65  728.90  729.2  730.75  733.25
# 3318 2021-04-27      730.75  735.00   757.50  727.35  748.6  749.15  747.67
# 3319 2021-04-28      749.15  755.00   760.00  741.10  743.4  746.25  751.02
# 3320 2021-04-29      746.25  753.20   765.85  743.40  746.4  746.75  753.06
# 3321 2021-04-30      746.75  739.00   759.45  724.50  726.4  730.05  743.35
#
#         Volume      Turnover  Deliverable Volume  %Deliverble YearMonth  \
# 0     27294366  2.687719e+15             9859619       0.3612   2007-11
# 1      4581338  4.312765e+14             1453278       0.3172   2007-11
# 2      5124121  4.550658e+14             1069678       0.2088   2007-11
# 3      4609762  4.283257e+14             1260913       0.2735   2007-11
# 4      2977470  2.875200e+14              816123       0.2741   2007-12
# ...        ...           ...                 ...          ...       ...
# 3317   9390549  6.885658e+14              838079       0.0892   2021-04
# 3318  20573107  1.538191e+15             1779639       0.0865   2021-04
# 3319  11156977  8.379106e+14             1342353       0.1203   2021-04
# 3320  13851910  1.043139e+15             1304895       0.0942   2021-04
# 3321  12600934  9.366911e+14             3514692       0.2789   2021-04
#
#       Symbol_ADANIPORTS  Symbol_MUNDRAPORT
# 0                 False               True
# 1                 False               True
# 2                 False               True
# 3                 False               True
# 4                 False               True
# ...                 ...                ...
# 3317               True              False
# 3318               True              False
# 3319               True              False
# 3320               True              False
# 3321               True              False
#
# [3322 rows x 15 columns]

# %%
# twitter
# from variables_to_specify_twitter import *

columns_to_normalize = ['Prev Close', 'Open', 'High', 'Low', 'Last','Close', 'VWAP', 'Volume', 'Turnover', 'Deliverable Volume','%Deliverble']
twitter_target_col = 'Close'
forecast_avg_target_col_name = 'forecast_avg_Close'
avg_target_col_name = 'avg_Close'
No_of_datapoints_in_one_day = 1
date_col_name = 'Date'
one_month_window_size = 31
one_month_days =31
out_columns = ['Training dataset', 'Testing dataset', 'mae', 'mse', 'rmse', 'r2', 'mape', 'training_time',
              'Testing Error', 'testing_time']

twitter_drop_columnss = [twitter_target_col]+['YearMonth']+[date_col_name]
twitter_windows = [50,150,310,450,600,750,900]

print(twitter_target_col)

from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
twitter_df[columns_to_normalize] = scaler.fit_transform(twitter_df[columns_to_normalize])

twitter_df = twitter_df.dropna().reset_index(drop=True)

twitter_time_steps = 1

daily_df_avg = twitter_df[['Close']].copy()
daily_df_avg.rename(columns={'Close': 'avg_Close'}, inplace=True)
twitter_df
# Out:
# Close
#            Date  Prev Close      Open      High       Low      Last     Close  \
# 0    2007-11-27    0.276794  0.550634  0.774216  0.570576  0.709167  0.712743
# 1    2007-11-28    0.712743  0.728634  0.724774  0.659896  0.647500  0.655217
# 2    2007-11-29    0.655217  0.666251  0.662766  0.631554  0.649167  0.647130
# 3    2007-11-30    0.647130  0.650447  0.698406  0.673638  0.684167  0.678269
# 4    2007-12-03    0.678269  0.691828  0.728895  0.701121  0.726667  0.718079
# ...         ...         ...       ...       ...       ...       ...       ...
# 3317 2021-04-26    0.514694  0.519859  0.518479  0.535277  0.517667  0.519196
# 3318 2021-04-27    0.519196  0.521522  0.533188  0.533946  0.533833  0.534537
# 3319 2021-04-28    0.534537  0.538158  0.535248  0.545755  0.529500  0.532119
# 3320 2021-04-29    0.532119  0.536660  0.540068  0.547730  0.532000  0.532536
# 3321 2021-04-30    0.532536  0.524849  0.534795  0.531498  0.515333  0.518613
#
#           VWAP    Volume  Turnover  Deliverable Volume  %Deliverble YearMonth  \
# 0     0.734103  0.279227  0.329318            0.439703     0.322305   2007-11
# 1     0.697799  0.046763  0.052818            0.064606     0.274102   2007-11
# 2     0.653161  0.052318  0.055733            0.047490     0.155346   2007-11
# 3     0.687572  0.047054  0.052456            0.056023     0.226227   2007-11
# 4     0.718129  0.030347  0.035202            0.036176     0.226884   2007-12
# ...        ...       ...       ...                 ...          ...       ...
# 3317  0.523459  0.095984  0.084346            0.037155     0.024321   2021-04
# 3318  0.535537  0.210436  0.188457            0.079169     0.021363   2021-04
# 3319  0.538344  0.114063  0.102646            0.059657     0.058392   2021-04
# 3320  0.540052  0.141645  0.127794            0.057985     0.029798   2021-04
# 3321  0.531919  0.128842  0.114750            0.156588     0.232143   2021-04
#
#       Symbol_ADANIPORTS  Symbol_MUNDRAPORT
# 0                 False               True
# 1                 False               True
# 2                 False               True
# 3                 False               True
# 4                 False               True
# ...                 ...                ...
# 3317               True              False
# 3318               True              False
# 3319               True              False
# 3320               True              False
# 3321               True              False
#
# [3322 rows x 15 columns]

# %% [markdown]
# # stationary

# %%
twitter_len_of_training_data_of_stationary_model =258

train = twitter_df[0:twitter_len_of_training_data_of_stationary_model] 
test = twitter_df[twitter_len_of_training_data_of_stationary_model:]

eval_df_first_month, stationary_model1 = twitter_stationary_model_with_hptuning(train, test, 2, out_columns, twitter_target_col, twitter_drop_columnss)

sum_training_time_stat1 = eval_df_first_month['training_time'].sum()
print('sum_training_time is: ', sum_training_time_stat1)
print(eval_df_first_month['Testing Error'].mean())
print("mae is : ", eval_df_first_month['mae'].mean())
# Out:
# Model Type: XGBRegressor
# Storage Required: 0.06 MB
# model storage is:  0.059329986572265625
#
#
# total_time is:  0.07054154199977347
# sum_training_time is:  0.06297770800028957
# 0.002962370976747866
# mae is :  0.03498902972827331

# %% [markdown]
# # Model reuse

# %% [markdown]
# Detected seasonality periods (ACF): [258 262 327 330 355 394 421 469 473 479 491]

# %%
# Model reuse
seasonality_periods_acf_ls, seasonality_periods_acf, segmented_daily_df_avg, filtered_most_similar_dict_wass, filtered_most_similar_dict_tvd, forecast_daily_df_avg, segmented_forecast_daily_df_avg, filtered_forecasted_most_similar_dict_wass, filtered_forecasted_most_similar_dict_tvd = get_seasonality_segments_and_similarities(daily_df_avg, avg_target_col_name, forecast_avg_target_col_name, 258)
seasonality_periods_acf = seasonality_periods_acf_ls[0]
# Out:
# Detected seasonality periods (ACF): [258 262 327 330 355 394 421 469 473 479 491]
# median_value is:  394

# %% [markdown]
# # drift detection

# %%
df_copy = twitter_df[[twitter_target_col]]
target_col = twitter_target_col
time_steps = twitter_time_steps
df_copy['date'] = pd.to_datetime(df_copy.index)
multiplier = twitter_time_steps
x = 258* multiplier
window_len_=[x]

drift_results_df_ls = []

for i in window_len_:
    start_drift_detection_time = timeit.default_timer()
    drift_results_df = detect_drift_univariate(
        df_copy,
        target_col=twitter_target_col,
        window_lengths=window_len_,
        arima_order=(1, 0, 0)
    )
    drift_results_df_ls.append(drift_results_df)
    drift_detection_time = timeit.default_timer() - start_drift_detection_time
    num_true = drift_results_df['drift_detected'].sum()
    print("i is: ", i, " and the Number of True values in 'drift_detected':", num_true, " total number of rows are : ", len(drift_results_df))
    print("drift detection time is: ", drift_detection_time)
    drift_results_df = drift_results_df_ls[0]
    drift_indices = list(drift_results_df.index[drift_results_df['drift_detected']])
    print("indices are: ", drift_indices)
# Out:
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# Fold 0: Train size=51, Test size=51
# Fold 1: Train size=102, Test size=51
# Fold 2: Train size=153, Test size=51
# Fold 3: Train size=204, Test size=51
# Skipping fold 4: Insufficient training or test data.
# i is:  258  and the Number of True values in 'drift_detected': 4  total number of rows are :  11
# drift detection time is:  1.9230982919998496
# indices are:  [0, 5, 8, 10]

# %%
eval_df_monthly2, avg_ml_storage1 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_most_similar_dict_wass, stationary_model1, twitter_len_of_training_data_of_stationary_model,twitter_df, "SA", twitter_target_col, twitter_drop_columnss, twitter_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 2)
# Out:
# window is:  258
# i/window is :  1.0
# Model Type: XGBRegressor
# Storage Required: 0.06 MB
#
#
# window is:  516
# i/window is :  2.0
# similar_month_index is :  0
# month_index:  2
#
#
#
#
# window is:  774
# i/window is :  3.0
# similar_month_index is :  1
# month_index:  3
#
#
#
# window is:  1032
# i/window is :  4.0
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  1290
# i/window is :  5.0
# similar_month_index is :  3
# previous_model_i is :  1290
# math.floor(previous_model_i/window) is:  5
# len(models_ls) is: 4
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  1548
# i/window is :  6.0
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  1806
# i/window is :  7.0
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2064
# i/window is :  8.0
# similar_month_index is :  6
# month_index:  8
#
#
#
#
# window is:  2322
# i/window is :  9.0
# similar_month_index is :  7
# month_index:  9
#
#
#
#
# window is:  2580
# i/window is :  10.0
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2838
# i/window is :  11.0
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  3096
#
#
# total_reuse_time is :  0.22938504200055831
# reuse_trained_and_stored_models_count is :  7
# avg_ml_storage:  0.03375734601702009
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.0031912573696958723
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.0014763524182527998
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.002005417863446825
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.002504088414261476
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.03718538354922631
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.017894941336054963
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.02383251748384163
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.030226984839607132
# Average mse in random model is:  0.03083978697164583
# average mae in random model is:  0.10949273611576991

# %%
eval_df_monthly2, avg_ml_storage2 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_most_similar_dict_tvd, stationary_model1, twitter_len_of_training_data_of_stationary_model,twitter_df, "SA", twitter_target_col, twitter_drop_columnss, twitter_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 2)
# Out:
# window is:  258
# i/window is :  1.0
# Model Type: XGBRegressor
# Storage Required: 0.06 MB
#
#
# window is:  516
# i/window is :  2.0
# similar_month_index is :  0
# month_index:  2
#
#
#
# window is:  774
# i/window is :  3.0
# similar_month_index is :  1
# month_index:  3
#
#
#
#
# window is:  1032
# i/window is :  4.0
# similar_month_index is :  0
# month_index:  4
#
#
#
#
# window is:  1290
# i/window is :  5.0
# similar_month_index is :  1
# month_index:  5
#
#
#
#
# window is:  1548
# i/window is :  6.0
# similar_month_index is :  1
# month_index:  6
#
#
#
#
# window is:  1806
# i/window is :  7.0
# similar_month_index is :  0
# month_index:  7
#
#
#
#
# window is:  2064
# i/window is :  8.0
# similar_month_index is :  6
# previous_model_i is :  2064
# math.floor(previous_model_i/window) is:  8
# len(models_ls) is: 7
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2322
# i/window is :  9.0
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2580
# i/window is :  10.0
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2838
# i/window is :  11.0
# similar_month_index is :  7
# previous_model_i is :  2838
# math.floor(previous_model_i/window) is:  11
# len(models_ls) is: 10
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
#
#
# window is:  3096
#
#
# total_reuse_time is :  0.23699491800152828
# reuse_trained_and_stored_models_count is :  5
# avg_ml_storage:  0.03863449096679687
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.0031912573696958723
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.0014763524182527998
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.0032118849502628696
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.0060826440891329605
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.03718538354922631
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.017894941336054963
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.03632089549786223
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.05719259155537506
# Average mse in random model is:  0.03083978697164583
# average mae in random model is:  0.10949273611576991

# %%
eval_df_monthly2, avg_ml_storage3 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_forecasted_most_similar_dict_wass, stationary_model1, twitter_len_of_training_data_of_stationary_model,twitter_df, "ES", twitter_target_col, twitter_drop_columnss, twitter_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 2)
# Out:
# window is:  258
# Model Type: XGBRegressor
# Storage Required: 0.06 MB
#
#
# window is:  516
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
#
#
# window is:  774
# similar_month_index is :  0
# month_index:  2
#
#
#
#
# window is:  1032
# similar_month_index is :  1
# month_index:  3
#
#
#
#
# window is:  1290
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  1548
# similar_month_index is :  3
# previous_model_i is :  1548
# math.floor(previous_model_i/window) is:  6
# len(models_ls) is: 5
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  1806
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2064
# similar_month_index is :  1
# month_index:  7
#
#
#
#
# window is:  2322
# similar_month_index is :  1
# month_index:  8
#
#
#
#
# window is:  2580
# similar_month_index is :  7
# previous_model_i is :  2580
# math.floor(previous_model_i/window) is:  10
# len(models_ls) is: 9
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2838
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  3096
#
#
# total_reuse_time is :  0.24641470800088427
# reuse_trained_and_stored_models_count is :  7
# avg_ml_storage:  0.03714152744838169
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.0031912573696958723
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.0014763524182527998
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.0035365361172036707
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.006446243208357251
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.03718538354922631
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.017894941336054963
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.03256807271718819
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.0681545348623846
# Average mse in random model is:  0.03083978697164583
# average mae in random model is:  0.10949273611576991

# %%
eval_df_monthly2, avg_ml_storage4 = new_copied_reuse_with_hptuning_no_while_loop_with_drift(filtered_forecasted_most_similar_dict_tvd, stationary_model1, twitter_len_of_training_data_of_stationary_model,twitter_df, "ES", twitter_target_col, twitter_drop_columnss, twitter_time_steps, seasonality_periods_acf, No_of_datapoints_in_one_day, drift_indices, 2)
# Out:
# window is:  258
# Model Type: XGBRegressor
# Storage Required: 0.06 MB
#
#
# window is:  516
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
#
#
# window is:  774
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
#
#
# window is:  1032
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  1290
# similar_month_index is :  2
# month_index:  4
#
#
#
#
# window is:  1548
# similar_month_index is :  1
# month_index:  5
#
#
#
# window is:  1806
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2064
# similar_month_index is :  4
# previous_model_i is :  2064
# math.floor(previous_model_i/window) is:  8
# len(models_ls) is: 7
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2322
# similar_month_index is :  2
# month_index:  8
#
#
#
#
# window is:  2580
# similar_month_index is :  4
# previous_model_i is :  2580
# math.floor(previous_model_i/window) is:  10
# len(models_ls) is: 9
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
#
#
# window is:  2838
# similar_month_index is :  8
# previous_model_i is :  2838
# math.floor(previous_model_i/window) is:  11
# len(models_ls) is: 10
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
#
#
# window is:  3096
#
#
# total_reuse_time is :  0.2755820410002343
# reuse_trained_and_stored_models_count is :  8
# avg_ml_storage:  0.038043975830078125
#
#
#
#
#
#
# mean_stationary_model_testing_error_of_months_in_similar_dict is:  0.0031912573696958723
# mean_periodical_testing_error_of_months_in_similar_dict is:  0.0014763524182527998
# mean_reused_model_testing_error_of_months_in_similar_dict is:  0.0035748815027059904
# mean_drift_model_testing_error_of_months_in_similar_dict is:  0.0043822938230911
#
#
# MAE results are:
# mae_mean_stationary_model_testing_error_mae_of_months_in_similar_dict is:  0.03718538354922631
# mae_mean_periodical_testing_error_mae_of_months_in_similar_dict is:  0.017894941336054963
# mae_mean_reused_model_testing_error_mae_of_months_in_similar_dict is:  0.026058244084740754
# mae_mean_drift_model_testing_error_mae_of_months_in_similar_dict is:  0.050565062176752544
# Average mse in random model is:  0.03083978697164583
# average mae in random model is:  0.10949273611576991

# %%
avg_ml_storage_reuse = (avg_ml_storage1+avg_ml_storage2+avg_ml_storage3+avg_ml_storage4)/4
print(avg_ml_storage_reuse)
# Out:
# 0.036894335065569196

# %% [markdown]
# # informed

# %%
informed_update(stationary_model1,twitter_df, target_col, twitter_drop_columnss,time_steps, seasonality_periods_acf,No_of_datapoints_in_one_day, drift_indices, 2)
# Out:
# window is:  258
# Model Type: XGBRegressor
# Storage Required: 0.06 MB
# window is:  516
# window is:  774
# window is:  1032
# window is:  1290
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# window is:  1548
# window is:  1806
# window is:  2064
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# window is:  2322
# window is:  2580
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# window is:  2838
# window is:  3096
# Informed total_time:  0.16620574999979
# avg_ml_storage:  0.038043975830078125

# %% [markdown]
# # periodical

# %%
periodical_retraining_with_hptuning(2, twitter_df, twitter_windows, out_columns, twitter_target_col, twitter_drop_columnss)
# Out:
# window is : 50
# window size is :  50
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# window is : 150
# window size is :  150
# Model Type: XGBRegressor
# Storage Required: 0.05 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.02 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# window is : 310
# window size is :  310
# Model Type: XGBRegressor
# Storage Required: 0.06 MB
# Model Type: XGBRegressor
# Storage Required: 0.05 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# window is : 450
# window size is :  450
# Model Type: XGBRegressor
# Storage Required: 0.07 MB
# Model Type: XGBRegressor
# Storage Required: 0.05 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# window is : 600
# window size is :  600
# Model Type: XGBRegressor
# Storage Required: 0.08 MB
# Model Type: XGBRegressor
# Storage Required: 0.05 MB
# Model Type: XGBRegressor
# Storage Required: 0.04 MB
# Model Type: XGBRegressor
# Storage Required: 0.05 MB
# window is : 750
# window size is :  750
# Model Type: XGBRegressor
# Storage Required: 0.09 MB
# Model Type: XGBRegressor
# Storage Required: 0.03 MB
# Model Type: XGBRegressor
# Storage Required: 0.05 MB
# window is : 900
# window size is :  900
# Model Type: XGBRegressor
# Storage Required: 0.09 MB
# Model Type: XGBRegressor
# Storage Required: 0.05 MB
# average model storage : 0.030399738658558238
# optimal MSE seg len time is: 0.10584854200033078
# mean_ls is:  [0.0017917961161023164, 0.0030921892381504537, 0.00571942751919777, 0.0015809715645718374, 0.003135892936155145, 0.0030045270645543457, 0.0006181869424930141]
# np.min(mean_ls) is :  0.0006181869424930141
# optimal_segment_number is : 900
#
#
#
#
# mean_ls_mae is:  [0.01929853492858585, 0.024559929268966236, 0.03318762151555216, 0.019124787571181127, 0.033949520113755086, 0.034126758049794204, 0.014423305818694679]
# np.min(mean_ls_mae) is :  0.014423305818694679
# optimal_segment_number_mae is : 900
# optimal MAE seg len time is: 0.10584854200033078
#
#
# total_time is:  3.330109167000046
# ([         Training dataset     Testing dataset       mae       mse      rmse  \
#   0   trained on window i-1  tested on window i  0.112462  0.016866  0.129868
#   1   trained on window i-1  tested on window i  0.023652  0.001393  0.037318
#   2   trained on window i-1  tested on window i  0.085632  0.008305  0.091134
#   3   trained on window i-1  tested on window i  0.089138  0.010304  0.101506
#   4   trained on window i-1  tested on window i  0.025372  0.001178  0.034321
#   ..                    ...                 ...       ...       ...       ...
#   60  trained on window i-1  tested on window i  0.029436  0.001262  0.035522
#   61  trained on window i-1  tested on window i  0.005019  0.000038  0.006191
#   62  trained on window i-1  tested on window i  0.002191  0.000007  0.002724
#   63  trained on window i-1  tested on window i  0.060760  0.005562  0.074576
#   64  trained on window i-1  tested on window i  0.098972  0.014326  0.119693
#
#             r2       mape  training_time  Testing Error  testing_time
#   0  -2.491905  28.463781       0.030600       0.016866      0.001394
#   1   0.874909   4.379537       0.029822       0.001393      0.001244
#   2  -6.783726  22.158371       0.024049       0.008305      0.001216
#   3  -3.122696  49.169494       0.020911       0.010304      0.001536
#   4  -0.106685  13.365250       0.021749       0.001178      0.001188
#   ..       ...        ...            ...            ...           ...
#   60 -0.695819  17.687334       0.021052       0.001262      0.001142
#   61  0.788427   2.702565       0.020727       0.000038      0.001374
#   62  0.900498   1.083489       0.019384       0.000007      0.001224
#   63 -1.857851  20.091117       0.020294       0.005562      0.001279
#   64 -2.145715  20.665835       0.021832       0.014326      0.001150
#
#   [65 rows x 10 columns],
#            Training dataset     Testing dataset       mae       mse      rmse  \
#   0   trained on window i-1  tested on window i  0.057410  0.005063  0.071158
#   1   trained on window i-1  tested on window i  0.050649  0.004042  0.063574
#   2   trained on window i-1  tested on window i  0.015999  0.000714  0.026715
#   3   trained on window i-1  tested on window i  0.108228  0.029251  0.171028
#   4   trained on window i-1  tested on window i  0.002101  0.000009  0.002992
#   5   trained on window i-1  tested on window i  0.001370  0.000006  0.002445
#   6   trained on window i-1  tested on window i  0.001241  0.000003  0.001828
#   7   trained on window i-1  tested on window i  0.003495  0.000025  0.005000
#   8   trained on window i-1  tested on window i  0.001087  0.000004  0.002097
#   9   trained on window i-1  tested on window i  0.026759  0.001562  0.039520
#   10  trained on window i-1  tested on window i  0.013388  0.000402  0.020053
#   11  trained on window i-1  tested on window i  0.002283  0.000017  0.004069
#   12  trained on window i-1  tested on window i  0.050208  0.003236  0.056886
#   13  trained on window i-1  tested on window i  0.003330  0.000043  0.006528
#   14  trained on window i-1  tested on window i  0.025989  0.001234  0.035127
#   15  trained on window i-1  tested on window i  0.010248  0.000154  0.012418
#   16  trained on window i-1  tested on window i  0.008227  0.000272  0.016498
#   17  trained on window i-1  tested on window i  0.018319  0.000458  0.021408
#   18  trained on window i-1  tested on window i  0.005674  0.000043  0.006556
#   19  trained on window i-1  tested on window i  0.024753  0.001431  0.037831
#   20  trained on window i-1  tested on window i  0.085000  0.016967  0.130257
#
#             r2        mape  training_time  Testing Error  testing_time
#   0   0.361343   30.316992       0.025858       0.005063      0.001256
#   1   0.519996   13.357593       0.025674       0.004042      0.001406
#   2   0.862467    3.177985       0.026620       0.000714      0.001270
#   3   0.478438  262.574167       0.028898       0.029251      0.001508
#   4   0.842452    8.657796       0.029215       0.000009      0.001458
#   5   0.946468    9.582471       0.024948       0.000006      0.001441
#   6   0.937965         inf       0.022477       0.000003      0.001297
#   7   0.589275   11.453721       0.019569       0.000025      0.001151
#   8   0.943582    3.063610       0.016686       0.000004      0.001273
#   9  -0.383986   26.834347       0.016194       0.001562      0.001223
#   10  0.081959    7.620027       0.017395       0.000402      0.001140
#   11  0.902764    1.218207       0.018668       0.000017      0.001204
#   12 -2.781093   56.104987       0.019013       0.003236      0.001176
#   13  0.940040    2.417087       0.023538       0.000043      0.001445
#   14 -0.523793   12.219935       0.024064       0.001234      0.001422
#   15  0.194643    4.196845       0.023296       0.000154      0.001314
#   16  0.317877    4.397713       0.030748       0.000272      0.001446
#   17 -0.038419    8.098617       0.028581       0.000458      0.001285
#   18  0.857610    2.404182       0.025416       0.000043      0.001293
#   19 -0.210181   18.149708       0.023732       0.001431      0.001311
#   20 -0.415745   20.602012       0.027858       0.016967      0.001574  ,
#           Training dataset     Testing dataset       mae           mse  \
#   0  trained on window i-1  tested on window i  0.004226  3.558947e-05
#   1  trained on window i-1  tested on window i  0.178173  4.104221e-02
#   2  trained on window i-1  tested on window i  0.004437  4.221565e-05
#   3  trained on window i-1  tested on window i  0.000638  7.204599e-07
#   4  trained on window i-1  tested on window i  0.089861  9.822488e-03
#   5  trained on window i-1  tested on window i  0.002696  2.030900e-05
#   6  trained on window i-1  tested on window i  0.011958  3.382206e-04
#   7  trained on window i-1  tested on window i  0.001636  5.136029e-06
#   8  trained on window i-1  tested on window i  0.005064  1.679541e-04
#
#          rmse        r2        mape  training_time  Testing Error  testing_time
#   0  0.005966  0.996057    1.136228       0.037811   3.558947e-05      0.001680
#   1  0.202589  0.129959  575.413138       0.037236   4.104221e-02      0.001573
#   2  0.006497  0.699546         inf       0.032924   4.221565e-05      0.001498
#   3  0.000849  0.988918    2.083083       0.035501   7.204599e-07      0.001553
#   4  0.099108 -4.591929   59.628789       0.039092   9.822488e-03      0.001667
#   5  0.004507  0.988492    2.904753       0.040619   2.030900e-05      0.001936
#   6  0.018391  0.822745    5.384464       0.033645   3.382206e-04      0.001651
#   7  0.002266  0.991270    0.737682       0.033162   5.136029e-06      0.001581
#   8  0.012960  0.881192    3.834704       0.035883   1.679541e-04      0.001424  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.045080  0.004135  0.064307
#   1  trained on window i-1  tested on window i  0.003270  0.000030  0.005436
#   2  trained on window i-1  tested on window i  0.046396  0.004764  0.069022
#   3  trained on window i-1  tested on window i  0.001824  0.000009  0.002939
#   4  trained on window i-1  tested on window i  0.015807  0.000511  0.022602
#   5  trained on window i-1  tested on window i  0.002372  0.000037  0.006116
#
#            r2        mape  training_time  Testing Error  testing_time
#   0  0.917575  142.197432       0.044615       0.004135      0.001865
#   1  0.771144         inf       0.036025       0.000030      0.001711
#   2 -0.461362   33.466020       0.027025       0.004764      0.001810
#   3  0.994423    1.440326       0.030925       0.000009      0.001539
#   4  0.495060    6.464813       0.027686       0.000511      0.001627
#   5  0.966895    1.659249       0.029843       0.000037      0.001483  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.089647  0.009553  0.097739
#   1  trained on window i-1  tested on window i  0.029416  0.002701  0.051968
#   2  trained on window i-1  tested on window i  0.004399  0.000081  0.008975
#   3  trained on window i-1  tested on window i  0.012337  0.000209  0.014473
#
#            r2       mape  training_time  Testing Error  testing_time
#   0  0.715490        inf       0.039069       0.009553      0.001864
#   1  0.150440  21.163763       0.035107       0.002701      0.001860
#   2  0.957473   2.963971       0.032810       0.000081      0.001744
#   3  0.567409   5.456123       0.033843       0.000209      0.001853  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.005890  0.000079  0.008916
#   1  trained on window i-1  tested on window i  0.080399  0.008421  0.091768
#   2  trained on window i-1  tested on window i  0.016091  0.000513  0.022642
#
#            r2       mape  training_time  Testing Error  testing_time
#   0  0.364108        inf       0.048722       0.000079      0.001860
#   1 -3.026260  56.093987       0.032069       0.008421      0.002048
#   2  0.354232   6.611687       0.037404       0.000513      0.002097  ,
#           Training dataset     Testing dataset       mae       mse      rmse  \
#   0  trained on window i-1  tested on window i  0.013544  0.000613  0.024750
#   1  trained on window i-1  tested on window i  0.015302  0.000624  0.024976
#
#            r2      mape  training_time  Testing Error  testing_time
#   0  0.775849       inf       0.056971       0.000613      0.002101
#   1  0.790506  7.042935       0.036375       0.000624      0.001890  ],
#  900,
#  6,
#  900,
#  6)
